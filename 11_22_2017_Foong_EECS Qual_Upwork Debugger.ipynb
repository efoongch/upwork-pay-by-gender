# %%
import httplib2
import oauth2
import urllib3
import types
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gender_detector import GenderDetector 
import psycopg2, psycopg2.extras
from causalinference import CausalModel
from causalinference.utils import random_data
import httplib
import base64
import json # For Microsoft Face API
import urllib as urllib # For Microsoft Face API
import time 
import csv
import datetime 

conn = psycopg2.connect("dbname=eureka01")
cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)
psycopg2.extensions.register_adapter(dict, psycopg2.extras.Json)
        
# Get detailed_info from workers in our database
cur.execute("SELECT detailed_info FROM upwork_worldwide_allskills_2017_10_21 WHERE user_id = '~01d9ddd8ad68ce6189';")

for row in cur:
    print json.dumps(row, indent=2)

        total_experience = 0
        work_experience_array = []
        
        try: 
            work_experience_list = user[0]["experiences"]["experience"]
            
        except:
            return 0
        
        if (type(work_experience_list) is list):
            count = 0
            total_overlap = 0
            for experience in work_experience_list:
                start_date = experience["exp_from"]
                end_date = experience["exp_to"]
                if (end_date == "Present"):
                    end_date = present_date
                start_datetime = datetime.datetime.strptime(start_date, "%m/%Y")
                end_datetime = datetime.datetime.strptime(end_date, "%m/%Y")
                work_experience_array.append([start_datetime, end_datetime])
                
                experience_duration = (end_datetime - start_datetime).days
                total_experience += experience_duration
            
            while (count < len(work_experience_array) - 1): # Check for overlap in work experience 
                start_newer = work_experience_array[count][0]
                end_newer = work_experience_array[count][1]
                start_older = work_experience_array[count+1][0]
                end_older = work_experience_array[count+1][1] 
                
                if (end_newer == end_older): # Pattern 1
                    newer_duration = (end_newer - start_newer).days
                    older_duration = (end_older - start_older).days
                    overlap = min(newer_duration, older_duration)
                    total_overlap += overlap 
                    count += 1
                    print "Pattern 1"
                    print overlap
                
                elif(start_older == start_newer): # Pattern 2
                    overlap = (end_older - start_older).days
                    total_overlap += overlap 
                    count += 1
                    print "Pattern 2"
                    print overlap
                
                elif(start_newer < start_older and end_newer > end_older): # Pattern 3
                    overlap = (end_older - start_older).days
                    total_overlap += overlap 
                    count += 1
                    print "Pattern 3"
                    print overlap
                
                elif(start_newer > start_older and end_newer > end_older and end_older > start_newer): # Pattern 4
                    overlap = (end_older - start_newer).days
                    total_overlap += overlap 
                    count += 1
                    print "Pattern 4"
                    print overlap 
                        
                else:
                    print "No overlap"
                    count += 1
                    
            total_experience = (total_experience - total_overlap)/30
            total_experience = total_experience/12 # Convert to years
            
            return total_experience
            
        elif (type(work_experience_list) is dict):
            start_date = work_experience_list["exp_from"]
            end_date = work_experience_list["exp_to"]
            if (end_date == "Present"):
                end_date = self.present_date
            start_datetime = datetime.datetime.strptime(start_date, "%m/%Y")
            end_datetime = datetime.datetime.strptime(end_date, "%m/%Y")          
            
            total_experience = ((end_datetime - start_datetime).days)/30
            total_experience = total_experience/12 # Convert to years
            
            return total_experience
        
        else: 
            return 0
# Out:
# [
#   {
#     "dev_adj_score_recent": "0",
#     "dev_ui_profile_access": "Public",
#     "dev_portrait": "https://odesk-prod-portraits.s3.amazonaws.com/Users:johnpaulgrant:PortraitUrl?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=wwSoaTOARcnSksP8OhD8gK9XGSA%3D",
#     "dev_country": "Australia",
#     "dev_first_name": "John",
#     "dev_groups": "",
#     "dev_city": "Wollongong",
#     "dev_blurb": "What I Can Help With?\n\nA strategy will be custom tailored to whatever you need to get going and grow your online business. This can include:\n\nAnalyzing your online setup for design, conversions, and maximum leverage from your existing traffic.\nHelping you with your overall strategic direction.\nGoing over your products and marketing to maximize sales.\nDefining a strategy for increasing traffic to your site.\nIdentifying profit opportunities you may have missed.\nThe list goes on\u2026\n\nWhy John?\n\nI have been obsessed with online business and online marketing since the internet came into existence. My first site was started back in 1997 and I developed that site into a successful online business. For the last 10 years I have been learning and implementing online marketing strategies for hundreds of websites, in many different industries.\n\nMy outlook on ecommerce comes from a solid understanding of marketing and influence. Knowing what makes people tick, how to communicate to them, and then putting that to use in your medium of choice (in my case, the Internet) is where you find real results. I am a long-time student of human nature, internet marketing and business. I also happen to have a solid foundation in the technical side of this business.\n\nI will pull no punches as I take a moment to float by own boat.  I know my stuff, and those who work with me come to find that out.\n\nBased In The Philippines\n\nI\u2019m an Australian, based in the Philippines \u2026 what does that mean for you? Cheaper hourly rates, with that familiar reliable western service.\n\nSites I Have Worked On\n\nBrady Australia\n\nBrady Australia owns a variety of websites in order to target different segments of the market. Websites include \u2026\n\nwww.seton.net.au\nwww.safetysignsservice.com.au\nwww.accidental.com.au\nwww.carroll.com.au\nwww.quikcrimp.com.au\nAll websites were under my scope.\n\nSeton Australia\n\nThe largest B2B ecommerce website in Australia, I was part of only a 2 man team who looked after all aspects of the online channel for the Australian branch of a global corporation.\n\nTasks I personally took care of on a regular basis were \u2026\n\nPPC / SEM (Google Adwords) Campaigns with a budget of $10,000 a month:\nSEO Campaigns:\nConversion Optimisation:\nEmail Marketing: Sent regular emails to over 100,000 subscribers\nInventory Maintenance: Maintained a database of over 30,000 sku\u2019s making it the largest B2B website in Australia.\nSocial Media: Implemented social media campaigns\nHighlights\n\nMigrated 4 sites with a new ecommerce platform (Magento)\nImplemented Google Adwords campaigns (PPC was not done before I got there) for half a dozen websites with spend over $10,000 per month and close to 10,000 keywords, which on a consistent basis at least at 1:5 ROI.\nImproved conversion rates by 1% resulting in additional sales amounting to $100,000\u2032s\nImproved & grew email newsletter campaigns. Moved to a new system which allowed for a lot more flexibility. Lists grew by 50,000 within a year.\nOnline channel reached an all time high in overall sales, amounting to approx. 20% of all sales.\nDoubled traffic to the site in the space of 18 months.\nTelstra\n\nTrading Post\n\nwww.tradingpost.com.au\n\nTrading post gave me the chance to build an offshore team to work on their link building & SEO, so to increase the exposure of their website.\n\nPayment Terms\n\nMy standard rate is $10 per hour, but I am flexible with this depending on the situation.",
#     "education": {
#       "institution": {
#         "ed_to": "01/2012",
#         "ed_area": "Internet Studies",
#         "ed_school": "Charles Sturt",
#         "ed_comment": "",
#         "ed_from": "01/2009",
#         "ed_degree": "Bachelors"
#       }
#     },
#     "dev_portrait_50": "https://odesk-prod-portraits.s3.amazonaws.com/Users:johnpaulgrant:PortraitUrl_50?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=6PR6GkBd8frfucGsIJBv8QEbMVk%3D",
#     "dev_profile_title": "Consultant",
#     "dev_portfolio_items_v2_count": "1",
#     "dev_adj_score": "4.791869834",
#     "dev_billed_assignments": "4",
#     "dev_portrait_100": "https://odesk-prod-portraits.s3.amazonaws.com/Users:johnpaulgrant:PortraitUrl_100?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=X0fcBenektzIjHeti4J05CwLqzM%3D",
#     "dev_recno": "272536",
#     "dev_portrait_32": "https://odesk-prod-portraits.s3.amazonaws.com/Users:johnpaulgrant:PortraitUrl_32?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=%2BdrAW9hFRaXnRPOdvVzVyT0G%2FBo%3D",
#     "portfolio_items": {
#       "portfolio_item": {
#         "pi_large_thumbnail": "",
#         "pi_image": "",
#         "pi_title": "Marketing of Australia's Largest B2B Ecommerce Website",
#         "pi_recno": "1015651"
#       }
#     },
#     "dev_bill_rate": "33.33",
#     "ciphertext": "~01d9ddd8ad68ce6189",
#     "experiences": {
#       "experience": {
#         "exp_from": "01/2009",
#         "exp_title_raw": "Web Development Manager",
#         "exp_comment": " ",
#         "exp_to": "12/2008",
#         "exp_company": "Apac Pacific"
#       }
#     },
#     "dev_timezone": "UTC+10:00 Sydney, Melbourne",
#     "dev_portfolio_items_count": "1",
#     "portfolio_items_v2": {
#       "portfolio_items_v": {
#         "pi_large_thumbnail": "",
#         "pi_recno": "446950183430922240",
#         "pi_title": "Marketing of Australia's Largest B2B Ecommerce Website",
#         "pi_image": ""
#       }
#     },
#     "tsexams": {
#       "tsexam": [
#         {
#           "ts_percentile": "97",
#           "ts_when": "03/14/2012",
#           "ts_pass": "1",
#           "ts_name_raw": "English Spelling Test (U.S. Version)",
#           "ts_score": "5.0000000000000000",
#           "ts_id": "4032697",
#           "ts_duration": "14"
#         },
#         {
#           "ts_percentile": "65",
#           "ts_duration": "2",
#           "ts_pass": "1",
#           "ts_name_raw": "oDesk Readiness Test for Independent Contractors and Staffing Managers",
#           "ts_score": "5.0000000000000000",
#           "ts_id": "4031363",
#           "ts_when": "03/14/2012"
#         },
#         {
#           "ts_percentile": "65",
#           "ts_when": "01/31/2012",
#           "ts_pass": "1",
#           "ts_name_raw": "oDesk Readiness Test for Independent Contractors and Staffing Managers",
#           "ts_score": "5.0000000000000000",
#           "ts_id": "3754935",
#           "ts_duration": "18"
#         },
#         {
#           "ts_percentile": "79",
#           "ts_when": "01/31/2012",
#           "ts_pass": "1",
#           "ts_name_raw": "Search Engine Optimization",
#           "ts_score": "3.2500000000000000",
#           "ts_id": "3754996",
#           "ts_duration": "19"
#         },
#         {
#           "ts_percentile": "45",
#           "ts_duration": "29",
#           "ts_pass": "1",
#           "ts_name_raw": "English To Tagalog (Filipino) Translation Skills",
#           "ts_score": "4.2500000000000000",
#           "ts_id": "4014777",
#           "ts_when": "03/12/2012"
#         },
#         {
#           "ts_percentile": "43",
#           "ts_duration": "27",
#           "ts_pass": "1",
#           "ts_name_raw": "U.S. English Basic Skills",
#           "ts_score": "3.4000000000000000",
#           "ts_id": "4031669",
#           "ts_when": "03/14/2012"
#         }
#       ]
#     },
#     "permalink": "",
#     "dev_eng_skill": "5",
#     "dev_last_activity": "January 8, 2015",
#     "job_categories": {
#       "job_category": [
#         {
#           "first_level": "Writing & Translation",
#           "seo_link": "Writers",
#           "second_level": "Website Content"
#         },
#         {
#           "first_level": "Writing & Translation",
#           "seo_link": "Writers",
#           "second_level": "Blog & Article Writing"
#         },
#         {
#           "first_level": "Customer Service",
#           "seo_link": "Customer Service Reps",
#           "second_level": "Customer Service & Support"
#         },
#         {
#           "first_level": "Customer Service",
#           "seo_link": "Customer Service Reps",
#           "second_level": "Technical Support"
#         },
#         {
#           "first_level": "Customer Service",
#           "seo_link": "Customer Service Reps",
#           "second_level": "Phone Support"
#         },
#         {
#           "first_level": "Sales & Marketing",
#           "seo_link": "Marketers",
#           "second_level": "Email Marketing"
#         },
#         {
#           "first_level": "Sales & Marketing",
#           "seo_link": "Marketers",
#           "second_level": "SEO - Search Engine Optimization"
#         },
#         {
#           "first_level": "Sales & Marketing",
#           "seo_link": "Marketers",
#           "second_level": "SEM - Search Engine Marketing"
#         },
#         {
#           "first_level": "Sales & Marketing",
#           "seo_link": "Marketers",
#           "second_level": "SMM - Social Media Marketing"
#         },
#         {
#           "first_level": "Sales & Marketing",
#           "seo_link": "Sales People",
#           "second_level": "Telemarketing & Telesales"
#         }
#       ]
#     },
#     "skills": {
#       "skill": [
#         {
#           "skl_name": "email-marketing",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Email_marketing",
#           "skl_rank": "3",
#           "skl_has_tests": "0",
#           "skl_description": "Email marketing is directly marketing a commercial message to a group of people using electronic mail email."
#         },
#         {
#           "skl_name": "email-technical-support",
#           "skl_description": "Technical support or tech support refers to a range of services by which enterprises provide assistance to users of technology products such as mobile phones, televisions, computers, software products or other electronic or mechanical goods.",
#           "skl_rank": "4",
#           "skl_has_tests": "0",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Technical_support"
#         },
#         {
#           "skl_name": "sem",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Search_engine_marketing",
#           "skl_rank": "2",
#           "skl_has_tests": "1",
#           "skl_description": "Search engine marketing, (SEM), is a form of Internet marketing that seeks to promote websites by increasing their visibility in search engine result pages (SERPs) through the use of paid placement, contextual advertising, and paid inclusion."
#         },
#         {
#           "skl_name": "seo",
#           "skl_description": "\"Search engine optimization (SEO) is the process of improving the visibility of a website or a web page in search engines via the \"\"natural\"\" or un-paid (\"\"organic\"\" or \"\"algorithmic\"\") search results.\"",
#           "skl_rank": "1",
#           "skl_has_tests": "1",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Search_engine_optimization"
#         }
#       ]
#     },
#     "dev_last_worked": "January 11, 2015",
#     "dev_tot_feedback": "3",
#     "dev_recno_ciphertext": "~01d9ddd8ad68ce6189",
#     "assignments": {
#       "hr": {
#         "job": [
#           {
#             "as_total_hours": "1107",
#             "as_rate": "$22.22",
#             "feedback": {
#               "comment": "I think... this is what love feels like...",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_to": "05/2015",
#             "as_total_hours_precise": "1107.16666663",
#             "as_opening_title": "Ecommerce and marketing manager",
#             "as_job_type": "Hourly",
#             "as_to_full": "05/16/2015"
#           },
#           {
#             "as_to": "04/2012",
#             "as_rate": "$10.21",
#             "feedback": {
#               "comment": "Competent contractor however we require more reporting on results.",
#               "score": "3.25",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "4",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "4",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "2",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "3",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "2",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "4",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_total_hours": "316",
#             "as_total_hours_precise": "315.83333336",
#             "as_opening_title": "Google Adwords",
#             "as_job_type": "Hourly",
#             "as_to_full": "04/23/2012"
#           },
#           {
#             "as_total_hours": "10.00",
#             "as_rate": "$11.11",
#             "as_to": "07/2012",
#             "as_total_hours_precise": "10",
#             "as_opening_title": "SEO, SMM, SEM & General Internet Marketing Genius",
#             "as_job_type": "Hourly",
#             "as_to_full": "07/13/2012"
#           }
#         ]
#       },
#       "fp": {
#         "job": {
#           "as_to": "09/2013",
#           "as_rate": "$0.00",
#           "as_total_charge": "177.78",
#           "as_total_hours": "0.00",
#           "as_total_hours_precise": "0",
#           "as_opening_title": "SEO writing and Social Media for a Local Business",
#           "as_job_type": "Fixed",
#           "as_to_full": "09/20/2013",
#           "feedback": {
#             "comment": "The SEO external building seemed to work alright however we still had a lot more to do. Good job on getting results for a difficult search phrase.",
#             "score": "4.00",
#             "scores": {
#               "score": [
#                 {
#                   "score": "4",
#                   "description": "competency and skills for the job, understanding of specifications/instructions",
#                   "label": "Skills"
#                 },
#                 {
#                   "score": "4",
#                   "description": "quality of work deliverables",
#                   "label": "Quality"
#                 },
#                 {
#                   "score": "5",
#                   "description": "online presence on a consistent schedule",
#                   "label": "Availability"
#                 },
#                 {
#                   "score": "4",
#                   "description": "ability to complete tasks on time",
#                   "label": "Deadlines"
#                 },
#                 {
#                   "score": "4",
#                   "description": "communication skills, frequent progress updates, responsiveness",
#                   "label": "Communication"
#                 },
#                 {
#                   "score": "3",
#                   "description": "cooperation and flexibility, suggestions for improvement",
#                   "label": "Cooperation"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "dev_job_categories_v2": {
#       "dev_job_categories_v": [
#         {
#           "name": "Other - Customer Service",
#           "groups": {
#             "group": {
#               "uid": "531770282580668417",
#               "name": "Customer Service"
#             }
#           }
#         },
#         {
#           "name": "Article & Blog Writing",
#           "groups": {
#             "group": {
#               "name": "Writing",
#               "uid": "531770282580668423"
#             }
#           }
#         },
#         {
#           "name": "Customer Service",
#           "groups": {
#             "group": {
#               "name": "Customer Service",
#               "uid": "531770282580668417"
#             }
#           }
#         },
#         {
#           "name": "Web Content",
#           "groups": {
#             "group": {
#               "uid": "531770282580668423",
#               "name": "Writing"
#             }
#           }
#         },
#         {
#           "name": "SEM - Search Engine Marketing",
#           "groups": {
#             "group": {
#               "uid": "531770282580668422",
#               "name": "Sales & Marketing"
#             }
#           }
#         },
#         {
#           "name": "Email & Marketing Automation",
#           "groups": {
#             "group": {
#               "name": "Sales & Marketing",
#               "uid": "531770282580668422"
#             }
#           }
#         },
#         {
#           "name": "Telemarketing & Telesales",
#           "groups": {
#             "group": {
#               "uid": "531770282580668422",
#               "name": "Sales & Marketing"
#             }
#           }
#         },
#         {
#           "name": "SEO - Search Engine Optimization",
#           "groups": {
#             "group": {
#               "name": "Sales & Marketing",
#               "uid": "531770282580668422"
#             }
#           }
#         },
#         {
#           "name": "SMM - Social Media Marketing",
#           "groups": {
#             "group": {
#               "uid": "531770282580668422",
#               "name": "Sales & Marketing"
#             }
#           }
#         },
#         {
#           "name": "Technical Support",
#           "groups": {
#             "group": {
#               "uid": "531770282580668417",
#               "name": "Customer Service"
#             }
#           }
#         }
#       ]
#     },
#     "dev_is_affiliated": "0",
#     "dev_ac_agencies": "",
#     "dev_short_name": "John G.",
#     "dev_last_worked_ts": "1420934400000",
#     "dev_total_hours": "1432.99999999",
#     "dev_last_name": " G."
#   }
# ]
