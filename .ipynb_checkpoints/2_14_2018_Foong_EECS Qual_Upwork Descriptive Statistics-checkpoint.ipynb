# %%
# %matplotlib inline
import httplib2
import oauth2
import urllib3
import types
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from causalinference import CausalModel
import httplib
import base64
import csv
from statsmodels.formula.api import ols
import statsmodels.api as sm
import math
from collections import defaultdict

data_analysis_file_name = './csv_files/formatted_analysis_df_2017_12_12_upwork_analysis_unitedstates_allskills.csv'
output_file_name = './analyses_output/descriptives_2017_12_12_upwork_analysis_unitedstates_allskills.txt'
        
merged = pd.read_csv(data_analysis_file_name)

# Merged2 refers to the omitted dataset
merged2 = merged[(merged['final_gender'] == 'unknown') | 
                 (merged['final_gender'] == 'ambiguous') | 
                  (merged['new_age_range_id'] == "0") |
                  (merged['new_age_range_id'] == "error") |
                  (merged['education'] == 'None') |
                  (merged['education'] == 'Other') | 
                  (merged['education'] == 'error') | 
                  (merged['work_experience'] == "error") |
                 (merged['job_category'] == "none")]
        
# Merged refers to the final dataset (copy these from Causal Inference python file)
merged = merged[merged['final_gender'] != 'unknown']
merged = merged[merged['final_gender'] != 'ambiguous']
merged = merged[merged['new_age_range_id'] != "0"]
merged = merged[merged['new_age_range_id'] != "error"]
merged = merged[merged['education'] != 'None']
merged = merged[merged['education'] != 'Other']
merged = merged[merged['education'] != 'error']
merged = merged[merged['work_experience'] != "error"]
merged = merged[merged['job_category'] != "none"]

# Testing out a hypothesis about removing legal folks
# merged = merged[merged['job_category'] != "Engineering & Architecture"]

merged['work_experience'] = merged['work_experience'].astype('float')

def make_dummy_gender(row):
    if row['final_gender'] == "female":
        return 0
    elif row['final_gender'] == "male":
        return 1
    
merged['dummy_gender'] = merged.apply(make_dummy_gender, axis=1)

print (merged)
# Out:
#        Unnamed: 0  user_count          worker_id_x  bill_rate  \
# 0               0           1  ~01293c7646ce6e3690      25.00
# 1               1           2  ~01532f4aeb4fca879d     100.00
# 2               2           3  ~0134509a6e6cfa6b56      50.00
# 3               3           4  ~0179ae7f91a5c34ffd      75.00
# 4               4           5  ~0116b3d444947fc9a4      40.00
# 5               5           6  ~017801fca5e36bc2b0     150.00
# 7               7           8  ~01fc37aa2ab464bebc      90.00
# 9               9          10  ~014eb38e7c47e575ba      50.00
# 10             10          11  ~014e2f7c22b13e7f0d      99.00
# 11             11          12  ~017ff330bf75de691c     125.00
# 12             12          13  ~018c6b21311c20a5a5      50.00
# 13             13          14  ~011b17916d988363b6      39.95
# 15             15          16  ~017bd87cc7d9355ec5      43.75
# 16             16          17  ~01e98a9e9635253206      55.00
# 17             17          18  ~01326e50b1b9848e36      75.00
# 18             18          19  ~01b2ad39234038145b      95.00
# 19             19          20  ~01d1cde17764edf5c8      55.00
# 20             20          21  ~0101dfd2d801cbf9ab      30.00
# 21             21          22  ~019453b3678e7b893d      60.00
# 22             22          23  ~014af483600013da34      50.00
# 26             26          27  ~01c8eb75451bbf1435      90.00
# 27             27          28  ~01c09ecc7ed2118cde      49.99
# 28             28          29  ~013742376364d46177      75.00
# 29             29          30  ~011ca595d3f07cb700      35.00
# 30             30          31  ~012a15a681c9fb57fc      90.00
# 31             31          32  ~016b2be2f770996261      30.00
# 32             32          33  ~0198a33ea07c12633d      45.00
# 34             34          35  ~01e41db1f8d86a09d0      45.00
# 35             35          36  ~016437a8dc0146d01a      35.00
# 37             37          38  ~0152a6a5ec3a5db5dd      49.00
# ...           ...         ...                  ...        ...
# 55485       55485       55486  ~01c4625d33e2e6f24b      35.00
# 55486       55486       55487  ~0197528716fffd0ffe      50.00
# 55487       55487       55488  ~01adbd45408911c145      25.00
# 55488       55488       55489  ~01961335927f754f4a      35.00
# 55489       55489       55490  ~01cd198e1bf16903c6      65.00
# 55490       55490       55491  ~01f5f908a1ead9b914      50.00
# 55491       55491       55492  ~01b3a25952325a58ee      30.00
# 55492       55492       55493  ~01b605388d03b8db71      55.00
# 55493       55493       55494  ~01bcfdbad8b98a1cc4      24.99
# 55494       55494       55495  ~011d711fd8cbc36eb1      25.00
# 55495       55495       55496  ~01c8dd88a8ce2c2713      25.00
# 55496       55496       55497  ~011ef11900d94b9638      30.00
# 55497       55497       55498  ~016ec098a9e5b287df      10.00
# 55498       55498       55499  ~012d7e60a5af8ce7a1      70.00
# 55499       55499       55500  ~012381e5d87c0e09e2      50.00
# 55500       55500       55501  ~019c8d58d01f9fceff     100.00
# 55501       55501       55502  ~013ee04600e235ae22      35.00
# 55502       55502       55503  ~0169f5def968463e75      40.00
# 55503       55503       55504  ~01cddf9b2fbcf31fa6       8.00
# 55504       55504       55505  ~0171ad2c497851af3f      50.00
# 55505       55505       55506  ~01db3d4882e94fe093      25.00
# 55506       55506       55507  ~0169ace1243be6a32f      65.00
# 55507       55507       55508  ~015f7d90b5b3b09b16      30.00
# 55508       55508       55509  ~01f5450ca2b0320f7b      30.00
# 55510       55510       55511  ~015325126b3c2f6461      30.00
# 55511       55511       55512  ~0159715e109fd69585      45.00
# 55512       55512       55513  ~013fd448bc0c15db31      35.00
# 55513       55513       55514  ~01d696e707503b6bd4     125.00
# 55514       55514       55515  ~01339bf00078492756      60.00
# 55516       55516       55517  ~01e70c9786fd5dcb92      50.00
#
#                      job_category  job_category_id  jobs_completed  \
# 0                     Translation                0               3
# 1               Sales & Marketing                1              27
# 2                 IT & Networking                2              14
# 3                         Writing                3              28
# 4                           Legal                4               5
# 5                           Legal                4              23
# 7                 IT & Networking                2             145
# 9                         Writing                3              71
# 10              Design & Creative                7              58
# 11                          Legal                4               7
# 12                        Writing                3              31
# 13              Design & Creative                7             114
# 15                        Writing                3              18
# 16              Sales & Marketing                1              27
# 17              Sales & Marketing                1               3
# 18              Sales & Marketing                1              14
# 19                IT & Networking                2               1
# 20              Design & Creative                7               4
# 21                        Writing                3               0
# 22              Sales & Marketing                1               1
# 26              Design & Creative                7               3
# 27                        Writing                3              28
# 28              Sales & Marketing                1              12
# 29                        Writing                3              61
# 30              Design & Creative                7             109
# 31     Web, Mobile & Software Dev                9               0
# 32              Design & Creative                7               0
# 34                  Admin Support               11               0
# 35                        Writing                3              10
# 37     Engineering & Architecture                5              97
# ...                           ...              ...             ...
# 55485  Engineering & Architecture                5               0
# 55486  Web, Mobile & Software Dev                9               0
# 55487           Design & Creative                7               0
# 55488               Admin Support               11               0
# 55489           Design & Creative                7               0
# 55490  Web, Mobile & Software Dev                9               0
# 55491           Design & Creative                7               0
# 55492  Web, Mobile & Software Dev                9               0
# 55493           Sales & Marketing                1               0
# 55494    Data Science & Analytics               10               0
# 55495  Engineering & Architecture                5               0
# 55496            Customer Service               12               0
# 55497  Web, Mobile & Software Dev                9               0
# 55498               Admin Support               11               0
# 55499  Web, Mobile & Software Dev                9               0
# 55500     Accounting & Consulting                8               0
# 55501    Data Science & Analytics               10               0
# 55502     Accounting & Consulting                8               0
# 55503  Web, Mobile & Software Dev                9               0
# 55504               Admin Support               11               0
# 55505           Design & Creative                7               0
# 55506           Design & Creative                7               0
# 55507           Design & Creative                7               0
# 55508               Admin Support               11               0
# 55510           Design & Creative                7               0
# 55511           Design & Creative                7               0
# 55512  Web, Mobile & Software Dev                9               0
# 55513  Web, Mobile & Software Dev                9               0
# 55514  Engineering & Architecture                5               0
# 55516           Design & Creative                7               0
#
#                                           profile_desc_x  hours_worked  \
# 0      I am a Spanish speaker from Argentina. I studi...    250.166667
# 1      Seasoned Public Relations Expert, Strategist &...     56.166667
# 2      I specialize in computing, web, and cloud solu...     27.000000
# 3      Charlena Berry offers Professional Business Se...    288.500000
# 4      I've drafted countless successful motions, con...      0.500000
# 5      I am a registered patent attorney and trademar...     29.166667
# 7      I have years of experience focusing on the mes...   1169.833333
# 9      I am a detail-oriented Dutch native with a PhD...    159.666667
# 10     Hi! I'm Scott Wallace, a full time voiceover p...      7.500000
# 11     Experienced attorney legal researcher, trial a...     68.000000
# 12     “Kasia did an amazing job with transforming my...     78.000000
# 13     5-Time National Creative Excellence Award Winn...    265.166667
# 15     Hello! \n\nMy name is Tyler and I am a healthc...     15.000000
# 16     This is a bold statement, but I stand behind m...    423.833333
# 17     Looking for dead end Facebook Ad campaigns and...      2.000000
# 18     "Paul was fantastic. Not only did he deliver q...      0.833333
# 19     Senior Program Manager successfully managed Mi...    130.833333
# 20     • Award-winning Video Editor for TV, film, com...    424.833333
# 21     Blogs:  I've written more than 300 blogs, on v...      0.000000
# 22     After 18+ years of experience in Fortune 500 c...      7.666667
# 26     As an instructional designer, content develope...     32.666667
# 27     Clear communication is the ultimate goal of ev...    613.500000
# 28     Management consulting company specializing in ...     17.000000
# 29     Tired of typos? Grammar getting grueling? Izzy...     41.166667
# 30     Creative Sound Design for Film & Digital Media...    450.300000
# 31     I enjoy being challenged and working on tasks ...      0.000000
# 32     Hello, and thank you for visiting my profile! ...      0.000000
# 34     I am a dependable and hard-working freelancer....      0.000000
# 35     I'm the Director and Tech Lead for the Digital...    371.500000
# 37     Over 20 years experience providing national br...    170.233333
# ...                                                  ...           ...
# 55485  I am a construction documentation expert that ...      0.000000
# 55486  Languages\t:\tC#.NET, XAML, HTML5\nWeb Technol...      0.000000
# 55487  On the front-end, I use a combination of HTML,...      0.000000
# 55488  My experience with a wide variety of project s...      0.000000
# 55489  With over 10 years experience working on set a...      0.000000
# 55490  ABOUT ACENDA\nAcenda is a cloud eCommerce plat...      0.000000
# 55491  Formally educated and self-taught marketing gu...      0.000000
# 55492  My depth of knowledge with .NET in the web, de...      0.000000
# 55493  I am a senior at the University of Pittsburgh ...      0.000000
# 55494  Engineering ● Statistics ● Research\nMasters d...      0.000000
# 55495  xperience with ROS, OpenCV and its simulation/...      0.000000
# 55496  Core Competencies and Strengths\n \n•\tAdobe I...      0.000000
# 55497  I am a Programmer that has been programming fo...      0.000000
# 55498  Experienced professional with solid history of...      0.000000
# 55499  I have a B.TECH From Anna university with firs...      0.000000
# 55500  My approach to financial management is designe...      0.000000
# 55501  For a lifelong lover of logic problems, math p...      0.000000
# 55502  \tBachelor of Science Degree in Accounting-Un...      0.000000
# 55503  I'm a skilled React developer with hands on ex...      0.000000
# 55504  I am a Technical Project Manager dedicated to ...      0.000000
# 55505  • Graphic Technician & Editor\t               ...      0.000000
# 55506  I am a Motion Graphic Designer with 8 years of...      0.000000
# 55507  Great Design Work Makes Your Business Shine!\n...      0.000000
# 55508  My goal is to help clients put together a mark...      0.000000
# 55510  I'm a guy who designs and sews. I've tackled a...      0.000000
# 55511  I work full time for a company that designs an...      0.000000
# 55512  I am a professional Civil Engineer, that has h...      0.000000
# 55513  My name is Mike Jones and I am the CEO of Capr...      0.000000
# 55514  I help you make the thing! \n\nFrom concept to...      0.000000
# 55516  I have over 25 years graphic design experience...      0.000000
#
#        feedback_score     ...       gender_pronoun  work_experience  \
# 0            5.000000     ...              unknown              5.0
# 1            4.954717     ...                 male              5.0
# 2            5.000000     ...                 male             15.0
# 3            4.966759     ...               female             12.0
# 4            5.000000     ...              unknown              2.0
# 5            5.000000     ...              unknown             18.0
# 7            4.901532     ...                 male              8.0
# 9            4.625865     ...               female             15.0
# 10           4.991592     ...              unknown             12.0
# 11           5.000000     ...              unknown             39.0
# 12           4.807041     ...              unknown              2.0
# 13           4.942109     ...                 male             13.0
# 15           4.944957     ...                 male              6.0
# 16           4.960260     ...              unknown              2.0
# 17           5.000000     ...                 male              4.0
# 18           5.000000     ...              unknown              1.0
# 19           0.000000     ...              unknown             25.0
# 20           0.000000     ...              unknown              0.0
# 21           0.000000     ...              unknown              0.0
# 22           4.000000     ...              unknown              3.0
# 26           4.832323     ...                 male             11.0
# 27           4.996591     ...               female             17.0
# 28           4.911264     ...                 male             37.0
# 29           4.935994     ...              unknown              5.0
# 30           4.996788     ...                 male              0.0
# 31           0.000000     ...              unknown              0.0
# 32           0.000000     ...              unknown              3.0
# 34           0.000000     ...              unknown             10.0
# 35           5.000000     ...                 male             14.0
# 37           4.954323     ...              unknown             12.0
# ...               ...     ...                  ...              ...
# 55485        0.000000     ...              unknown              0.0
# 55486        0.000000     ...              unknown              6.0
# 55487        0.000000     ...              unknown              0.0
# 55488        0.000000     ...              unknown              3.0
# 55489        0.000000     ...              unknown              0.0
# 55490        0.000000     ...              unknown              0.0
# 55491        0.000000     ...              unknown              4.0
# 55492        0.000000     ...              unknown             10.0
# 55493        0.000000     ...              unknown              1.0
# 55494        0.000000     ...              unknown              4.0
# 55495        0.000000     ...              unknown              0.0
# 55496        0.000000     ...              unknown              9.0
# 55497        0.000000     ...              unknown              0.0
# 55498        0.000000     ...              unknown              6.0
# 55499        0.000000     ...              unknown             13.0
# 55500        0.000000     ...              unknown              0.0
# 55501        0.000000     ...              unknown              0.0
# 55502        0.000000     ...              unknown              0.0
# 55503        0.000000     ...              unknown              0.0
# 55504        0.000000     ...              unknown              0.0
# 55505        0.000000     ...              unknown             12.0
# 55506        0.000000     ...              unknown              2.0
# 55507        0.000000     ...              unknown             19.0
# 55508        0.000000     ...              unknown              8.0
# 55510        0.000000     ...              unknown              2.0
# 55511        0.000000     ...              unknown              0.0
# 55512        0.000000     ...              unknown              9.0
# 55513        0.000000     ...              unknown              0.0
# 55514        0.000000     ...              unknown             12.0
# 55516        0.000000     ...              unknown             12.0
#
#                        education education_id ed_list new_age_range_id  \
# 0             Bachelor or Higher            0      []                3
# 1             Bachelor or Higher            0      []                4
# 2             Bachelor or Higher            0      []                3
# 3             Bachelor or Higher            0      []                4
# 4             Bachelor or Higher            0      []                3
# 5             Bachelor or Higher            0      []                4
# 7             Bachelor or Higher            0      []                4
# 9             Bachelor or Higher            0      []                3
# 10            Bachelor or Higher            0      []                4
# 11            Bachelor or Higher            0      []                7
# 12            Bachelor or Higher            0      []                3
# 13            Bachelor or Higher            0      []                4
# 15            Bachelor or Higher            0      []                6
# 16     Some College or Associate            1      []                3
# 17            Bachelor or Higher            0      []                4
# 18            Bachelor or Higher            0      []                3
# 19            Bachelor or Higher            0      []                4
# 20            Bachelor or Higher            0      []                6
# 21            Bachelor or Higher            0      []                4
# 22     Some College or Associate            1      []                7
# 26            Bachelor or Higher            0      []                4
# 27            Bachelor or Higher            0      []                3
# 28            Bachelor or Higher            0      []                5
# 29            Bachelor or Higher            0      []                4
# 30            Bachelor or Higher            0      []                3
# 31            Bachelor or Higher            0      []                5
# 32     Some College or Associate            1      []                6
# 34            Bachelor or Higher            0      []                3
# 35            Bachelor or Higher            0      []                4
# 37            Bachelor or Higher            0      []                4
# ...                          ...          ...     ...              ...
# 55485         Bachelor or Higher            0      []                7
# 55486         Bachelor or Higher            0      []                4
# 55487         Bachelor or Higher            0      []                3
# 55488         Bachelor or Higher            0      []                4
# 55489  Some College or Associate            1      []                4
# 55490         Bachelor or Higher            0      []                4
# 55491         Bachelor or Higher            0      []                3
# 55492         Bachelor or Higher            0      []                4
# 55493         Bachelor or Higher            0      []                3
# 55494         Bachelor or Higher            0      []                3
# 55495         Bachelor or Higher            0      []                3
# 55496                High School            2      []                3
# 55497                High School            2      []                3
# 55498         Bachelor or Higher            0      []                2
# 55499         Bachelor or Higher            0      []                4
# 55500         Bachelor or Higher            0      []                4
# 55501         Bachelor or Higher            0      []                4
# 55502         Bachelor or Higher            0      []                4
# 55503         Bachelor or Higher            0      []                7
# 55504         Bachelor or Higher            0      []                2
# 55505         Bachelor or Higher            0      []                4
# 55506         Bachelor or Higher            0      []                5
# 55507                High School            2      []                3
# 55508         Bachelor or Higher            0      []                3
# 55510         Bachelor or Higher            0      []                4
# 55511  Some College or Associate            1      []                3
# 55512         Bachelor or Higher            0      []                4
# 55513         Bachelor or Higher            0      []                4
# 55514  Some College or Associate            1      []                5
# 55516  Some College or Associate            1      []                4
#
#       disagree_w_faceapi firstname_gender final_gender dummy_gender
# 0                  False           female       female            0
# 1                  False             male         male            1
# 2                  False             male         male            1
# 3                  False           female       female            0
# 4                  False          unknown         male            1
# 5                  False             male         male            1
# 7                  False             male         male            1
# 9                  False           female       female            0
# 10                 False             male         male            1
# 11                 False          unknown         male            1
# 12                 False           female       female            0
# 13                 False             male         male            1
# 15                 False          unknown         male            1
# 16                 False             male         male            1
# 17                 False             male         male            1
# 18                 False             male         male            1
# 19                 False             male         male            1
# 20                  True           female       female            0
# 21                  True             male         male            1
# 22                 False             male         male            1
# 26                 False             male         male            1
# 27                  True           female       female            0
# 28                 False             male         male            1
# 29                 False           female       female            0
# 30                 False             male         male            1
# 31                  True             male         male            1
# 32                 False             male         male            1
# 34                 False           female       female            0
# 35                 False             male         male            1
# 37                 False             male         male            1
# ...                  ...              ...          ...          ...
# 55485              False             male         male            1
# 55486              False             male         male            1
# 55487              False          unknown         male            1
# 55488              False          unknown       female            0
# 55489              False             male         male            1
# 55490              False             male         male            1
# 55491              False          unknown         male            1
# 55492              False             male         male            1
# 55493              False             male         male            1
# 55494              False          unknown       female            0
# 55495              False          unknown         male            1
# 55496              False           female       female            0
# 55497              False          unknown         male            1
# 55498              False          unknown       female            0
# 55499              False             male         male            1
# 55500              False           female       female            0
# 55501              False          unknown         male            1
# 55502               True             male         male            1
# 55503              False             male         male            1
# 55504              False          unknown         male            1
# 55505               True           female       female            0
# 55506               True             male         male            1
# 55507               True           female       female            0
# 55508              False           female       female            0
# 55510              False          unknown         male            1
# 55511              False             male         male            1
# 55512              False             male         male            1
# 55513              False          unknown         male            1
# 55514              False             male         male            1
# 55516              False             male         male            1
#
# [48035 rows x 32 columns]

# %% [markdown]
# ## Creating Dumbbell Chart

# %%
# Create arrays of the average hourly bill rate in each job category

job_categories_list = ["Accounting & Consulting", "Admin Support", "Customer Service", "Data Science & Analytics",
                      "Design & Creative", "Engineering & Architecture", "IT & Networking", 
                      "Legal", "Sales & Marketing", "Translation", "Web, Mobile & Software Dev", 
                      "Writing"]

female_rates = []
male_rates = []

for job in job_categories_list:
    # Calculate female earnings
    df_female_dumbbell = merged[(merged['job_category'] == job) & (merged['final_gender'] == "female")]
    female_mean = round(np.mean(df_female_dumbbell['bill_rate']), 0)
    female_mean = int(female_mean)

    # Calculate male earnings
    df_male_dumbbell = merged[(merged['job_category'] == job) & (merged['final_gender'] == "male")]
    male_mean = round(np.mean(df_male_dumbbell['bill_rate']), 0)
    male_mean = int(male_mean)

    female_rates.append(female_mean)
    male_rates.append(male_mean)

print female_rates
print male_rates
# Out:
# [53, 25, 23, 46, 39, 41, 48, 53, 48, 28, 43, 34]
# [68, 28, 30, 49, 42, 47, 61, 82, 57, 29, 48, 39]

# %%
########## Modify Below ##########
# how many categories you have?
N = 12
# labels for categories (must have N labels)
axis_labels = ["Accounting & Consulting", "Admin Support", "Customer Service", "Data Science & Analytics",
                      "Design & Creative", "Engineering & Architecture", "IT & Networking", 
                      "Legal", "Sales & Marketing", "Translation", "Web, Mobile & Software Dev", 
                      "Writing"]
# First dumbbell values (must have N values)
a = female_rates
# Second dumbbell values (must have N values)
b = male_rates
A_COLOR = '#EA2BA2'  # Color to plot a values
B_COLOR = '#006666'  # Color to plot b values
LINE_COLOR = '#000000'  # Color to plot the line between dumbbells
REVERSED_ORDER = True  # Order of plotting (False: bottom to top. True: top to bottom)
########## Modify Above ##########

# Styles to be used when plotting the different elements of the graph.
dumbbell_style_a = dict(color=A_COLOR, marker='o', markersize=15)
dumbbell_style_b = dict(color=B_COLOR, marker='o', markersize=15)
line_style = dict(color=LINE_COLOR, linestyle='-')
axis_label_style = dict(horizontalalignment='right', verticalalignment='center', fontsize=12,
                        fontdict={'family': 'monospace'})
data_label_style = dict(horizontalalignment='center', verticalalignment='center', color='white', weight='bold',
                        fontsize=8, fontdict={'family': 'monospace'})

# By default, data will be plotted bottom to top. If True, this will reverse the order (top to bottom)
if (REVERSED_ORDER):
    a.reverse()
    b.reverse()
    axis_labels.reverse()

# Create the figure
fig = plt.figure()
ax = fig.add_subplot(111)

# Get min and max values (for plotting purposes)
min = min([min(a), min(b)]) - 1
max = max([max(a), max(b)]) + 1

index = list(range(N))
# Loop N times
for i in index:
    # Plot the line between dumbbells
    ax.plot([a[i], b[i]], [i, i], **line_style)
    # Plot the dumbbells.
    ax.plot(a[i], i, **dumbbell_style_a)
    ax.plot(b[i], i, **dumbbell_style_b)
    # Add data label on top of dumbbells
    ax.text(a[i], i, a[i], **data_label_style)
    ax.text(b[i], i, b[i], **data_label_style)
    # Add the axis label
    ax.text(min, i, axis_labels[i], **axis_label_style)

# Adjust and save the figure
fig.subplots_adjust(left=0.3) # Depending on your data, you might not need this adjustment.
ax.set_axis_off()
plt.xlim(min, max)
plt.ylim(-1, N)
plt.savefig('dumbbell.png', dpi=300)
plt.show()
# Out:
# <type 'list'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-2024bfe68f1d> in <module>()
#      38
#      39 # Get min and max values (for plotting purposes)
# ---> 40 min1 = min([min(a), min(b)]) - 1
#      41 max1 = max([max(a), max(b)]) + 1
#      42
#
# TypeError: 'float' object is not callable

# %% [markdown]
# ## Comparing age ranges across our final and BLS dataset

# %%
index = ["16-19", "20-24", "25-34", "35-44", "45-54", "55-64"]
columns = ['Final Upwork Sample', 'BLS Dataset']

final_age_percentages = [1.41, 11.06, 50.41, 26.83, 7.40, 1.77, 1.11]
bls_age_percentages = [1.16, 7.91, 24.71, 22.76, 23.10, 16.65, 3.72]

bls_age_comparison_df = pd.DataFrame(index=index, columns=columns)

current_index = 0
for index, row in bls_age_comparison_df.iterrows():
    row['Final Upwork Sample'] = final_age_percentages[current_index]
    row['BLS Dataset'] = bls_age_percentages[current_index]
    current_index += 1

graph = bls_age_comparison_df.plot(kind="bar", figsize=(10,5))
plt.xticks(rotation='horizontal')
graph.set_xlabel("Age Range (Years)")
graph.set_ylabel("Percentage of Dataset (%)")

# %% [markdown]
# ## Comparing Education Level Across Samples

# %%
index = ["Less Than a\nHigh School Diploma", "High School Graduates,\nNo College", 
         "Some College or\nAssociate's Degree", "Bachelor's Degree\nor Higher"]
columns = ['Final Upwork Sample', 'BLS Dataset']

final_percentages = [1.58, 2.79, 19.37, 76.26]
bls_percentages = [7.04, 25.22, 27.03, 40.71]

bls_comparison_df = pd.DataFrame(index=index, columns=columns)

current_index = 0
for index, row in bls_comparison_df.iterrows():
    row['Final Upwork Sample'] = final_percentages[current_index]
    row['BLS Dataset'] = bls_percentages[current_index]
    current_index += 1

graph = bls_comparison_df.plot(kind="bar", figsize=(10,5))
plt.xticks(rotation='horizontal')
graph.set_xlabel("Education Level")
graph.set_ylabel("Percentage of Dataset (%)")

# %% [markdown]
# ## Making pay equal across categories

# %%
job_categories_list = ["Accounting & Consulting", "Admin Support", "Customer Service", "Data Science & Analytics",
                      "Design & Creative", "Engineering & Architecture", "IT & Networking", 
                      "Legal", "Sales & Marketing", "Translation", "Web, Mobile & Software Dev", 
                      "Writing"]

pay_dict = defaultdict(list)


def equalize_within_category():
    for job in job_categories_list:
        # Calculate female earnings
        df_female = merged[(merged['job_category'] == job) & (merged['final_gender'] == "female")]
        female_mean = np.mean(df_female['bill_rate'])
        female_median = np.median(df_female['bill_rate'])
        
        # Calculate male earnings
        df_male = merged[(merged['job_category'] == job) & (merged['final_gender'] == "male")]
        male_mean = np.mean(df_male['bill_rate'])
        male_median = np.median(df_male['bill_rate'])
        
        # Calculate weights
        female_weight = len(df_female.index)
        male_weight = len(df_male.index)
        
        pay_dict[job].append(female_mean)
        pay_dict[job].append(female_weight)
        pay_dict[job].append(male_mean)
        pay_dict[job].append(male_weight)
        

equalize_within_category()

# Assuming pay is equal within categories
def make_equal_pay_female(row):
    job = row['job_category']
    return pay_dict[job][0]

def make_equal_pay_male(row):
    job = row['job_category']
    return pay_dict[job][2]

merged['equal_pay_female'] = merged.apply(make_equal_pay_female, axis=1)
merged['equal_pay_male'] = merged.apply(make_equal_pay_male, axis=1)

# Assuming proportions are equal within categories
# Calculate appropriate weight for each row in the dataset

female_weights = []
male_weights = []



for category in pay_dict:
    female_count = int(pay_dict[category][1])
    male_count = int(pay_dict[category][3])
    
    # Using female weights
    female_weight = float(female_count)/float(male_count)
    
    # Using male weights
    male_weight = float(male_count)/float(female_count)
    
    pay_dict[category].append(female_weight)
    pay_dict[category].append(male_weight)

print (pay_dict)

for index, row in merged.iterrows():
    job = row['job_category']
    if row['final_gender'] == "female":
        female_weights.append(1)
        male_weights.append(pay_dict[job][5])
    elif row['final_gender'] == "male":
        female_weights.append(pay_dict[job][4])
        male_weights.append(1)

print (female_weights)
print (male_weights)
# Out:
# defaultdict(<type 'list'>, {'Web, Mobile & Software Dev': [42.64274887604367, 1557, 48.454136955291425, 5301, 0.2937181663837012, 3.4046242774566475], 'Customer Service': [22.5434375, 768, 30.021658986175115, 434, 1.7695852534562213, 0.5651041666666666], 'IT & Networking': [47.916556776556774, 273, 60.842657869934015, 1061, 0.2573044297832234, 3.8864468864468864], 'Legal': [52.754439252336454, 214, 82.15657894736842, 152, 1.4078947368421053, 0.7102803738317757], 'Writing': [33.663614574898794, 6175, 38.660774428274436, 3848, 1.6047297297297298, 0.6231578947368421], 'Data Science & Analytics': [46.12910416666667, 480, 48.527651217596215, 1273, 0.3770620581304006, 2.652083333333333], 'Design & Creative': [38.78878239903556, 4977, 41.97629252782192, 6290, 0.7912559618441971, 1.263813542294555], 'Accounting & Consulting': [53.3026641221374, 1310, 68.44427530954115, 1373, 0.9541150764748726, 1.048091603053435], 'Admin Support': [24.753073694029847, 4288, 27.802085492227974, 1544, 2.77720207253886, 0.36007462686567165], 'Engineering & Architecture': [40.892516778523486, 298, 46.78637134778511, 1061, 0.28086710650329877, 3.5604026845637584], 'Sales & Marketing': [48.18509782608696, 1840, 56.92184886649875, 1985, 0.9269521410579346, 1.078804347826087], 'Translation': [27.603661202185798, 915, 28.629805825242727, 618, 1.4805825242718447, 0.6754098360655738]})
# [1, 0.9269521410579346, 0.2573044297832234, 1, 1.4078947368421053, 1.4078947368421053, 0.2573044297832234, 1, 0.7912559618441971, 1.4078947368421053, 1, 0.7912559618441971, 1.6047297297297298, 0.9269521410579346, 0.9269521410579346, 0.9269521410579346, 0.2573044297832234, 1, 1.6047297297297298, 0.9269521410579346, 0.7912559618441971, 1, 0.9269521410579346, 1, 0.7912559618441971, 0.2937181663837012, 0.7912559618441971, 1, 1.6047297297297298, 0.28086710650329877, 1, 0.7912559618441971, 2.77720207253886, 1, 1, 1, 1, 1, 0.9269521410579346, 1, 0.2937181663837012, 1, 1.4078947368421053, 1, 0.9541150764748726, 1.6047297297297298, 0.7912559618441971, 0.9269521410579346, 1, 1, 0.7912559618441971, 1, 0.9269521410579346, 1.6047297297297298, 1.6047297297297298, 1, 0.9269521410579346, 1, 0.3770620581304006, 1.6047297297297298, 1, 0.2937181663837012, 0.2937181663837012, 1, 1, 1, 0.7912559618441971, 0.9269521410579346, 0.9269521410579346, 2.77720207253886, 1, 1, 1.6047297297297298, 1.4805825242718447, 1.6047297297297298, 1.6047297297297298, 1, 1, 1.6047297297297298, 0.3770620581304006, 0.2937181663837012, 1, 1.6047297297297298, 1, 1, 0.2573044297832234, 1, 0.7912559618441971, 0.7912559618441971, 1, 1, 0.28086710650329877, 0.28086710650329877, 0.3770620581304006, 1, 0.7912559618441971, 0.2937181663837012, 1.6047297297297298, 1.7695852534562213, 0.3770620581304006, 0.28086710650329877, 0.9269521410579346, 1.6047297297297298, 1, 0.7912559618441971, 1, 1, 0.7912559618441971, 1, 1.6047297297297298, 2.77720207253886, 0.3770620581304006, 0.2573044297832234, 1, 1, 0.2573044297832234, 1, 1, 1, 1, 1, 1, 1.6047297297297298, 1, 2.77720207253886, 1, 1, 1, 1, 1, 1, 0.9269521410579346, 0.9269521410579346, 0.9269521410579346, 0.2937181663837012, 1, 0.2573044297832234, 1, 1.6047297297297298, 0.7912559618441971, 1, 1, 0.9541150764748726, 0.2573044297832234, 1.6047297297297298, 1.6047297297297298, 0.7912559618441971, 0.3770620581304006, 0.3770620581304006, 1, 1, 1, 1, 1, 1.6047297297297298, 1.6047297297297298, 1, 0.2937181663837012, 0.7912559618441971, 1, 1, 1.6047297297297298, 1, 1, 1, 0.9269521410579346, 0.7912559618441971, 0.7912559618441971, 1, 1, 1.7695852534562213, 1.6047297297297298, 1.6047297297297298, 1, 1, 1, 1, 0.2937181663837012, 1, 1.6047297297297298, 0.3770620581304006, 1.6047297297297298, 1, 0.2937181663837012, 1, 1, 0.2573044297832234, 1, 1, 1, 0.2937181663837012, 1, 0.7912559618441971, 1.4805825242718447, 1.4078947368421053, 0.7912559618441971, 0.9269521410579346, 1, 1, 1.4805825242718447, 1, 1.6047297297297298, 0.7912559618441971, 0.9541150764748726, 1, 0.7912559618441971, 1, 1, 1.4078947368421053, 1, 0.9541150764748726, 0.9269521410579346, 0.3770620581304006, 0.7912559618441971, 1.4078947368421053, 0.2937181663837012, 0.9269521410579346, 1, 1, 1.6047297297297298, 1, 0.28086710650329877, 1, 0.2573044297832234, 1.6047297297297298, 0.7912559618441971, 0.2937181663837012, 0.9269521410579346, 0.9269521410579346, 1.6047297297297298, 1, 1.6047297297297298, 0.2937181663837012, 1, 1, 0.2937181663837012, 1.6047297297297298, 1.4078947368421053, 1, 1.6047297297297298, 1, 0.2573044297832234, 1, 0.9269521410579346, 1.6047297297297298, 1, 1.6047297297297298, 0.28086710650329877, 1, 1, 0.2937181663837012, 1.6047297297297298, 0.3770620581304006, 1, 1, 0.7912559618441971, 0.9269521410579346, 1, 1, 1, 0.7912559618441971, 0.28086710650329877, 0.9541150764748726, 1, 1, 0.7912559618441971, 0.7912559618441971, 1, 0.7912559618441971, 1, 1, 0.2937181663837012, 1, 0.3770620581304006, 0.7912559618441971, 0.7912559618441971, 0.7912559618441971, 0.7912559618441971, 1, 1.6047297297297298, 1, 0.2937181663837012, 0.28086710650329877, 0.2937181663837012, 0.3770620581304006, 0.7912559618441971, 1, 1.6047297297297298, 1, 1.6047297297297298, 1, 1.6047297297297298, 1, 1, 1, 1.6047297297297298, 1.6047297297297298, 1.6047297297297298, 1.4078947368421053, 0.2937181663837012, 1.6047297297297298, 0.9541150764748726, 1, 0.2937181663837012, 1, 1, 1, 1, 1.6047297297297298, 0.2573044297 ...
# [0.6754098360655738, 1, 1, 0.6231578947368421, 1, 1, 1, 0.6231578947368421, 1, 1, 0.6231578947368421, 1, 1, 1, 1, 1, 1, 1.263813542294555, 1, 1, 1, 0.6231578947368421, 1, 0.6231578947368421, 1, 1, 1, 0.36007462686567165, 1, 1, 2.652083333333333, 1, 1, 0.6231578947368421, 0.36007462686567165, 0.6754098360655738, 0.6231578947368421, 3.4046242774566475, 1, 1.263813542294555, 1, 2.652083333333333, 1, 0.6231578947368421, 1, 1, 1, 1, 0.6231578947368421, 0.36007462686567165, 1, 0.6231578947368421, 1, 1, 1, 1.263813542294555, 1, 0.6231578947368421, 1, 1, 1.078804347826087, 1, 1, 0.6231578947368421, 1.263813542294555, 0.6231578947368421, 1, 1, 1, 1, 0.6231578947368421, 1.078804347826087, 1, 1, 1, 1, 1.078804347826087, 3.5604026845637584, 1, 1, 1, 0.6231578947368421, 1, 0.6231578947368421, 1.263813542294555, 1, 1.263813542294555, 1, 1, 0.6231578947368421, 0.6231578947368421, 1, 1, 1, 1.263813542294555, 1, 1, 1, 1, 1, 1, 1, 1, 0.6231578947368421, 1, 0.6231578947368421, 0.6231578947368421, 1, 0.36007462686567165, 1, 1, 1, 1, 0.6231578947368421, 0.36007462686567165, 1, 1.263813542294555, 3.5604026845637584, 0.6231578947368421, 0.36007462686567165, 0.6231578947368421, 3.8864468864468864, 1, 0.6231578947368421, 1, 0.6231578947368421, 1.263813542294555, 1.048091603053435, 2.652083333333333, 0.6231578947368421, 3.4046242774566475, 1, 1, 1, 1, 1.263813542294555, 1, 3.4046242774566475, 1, 1, 1.078804347826087, 0.6231578947368421, 1, 1, 1, 1, 1, 1, 1, 1.263813542294555, 3.4046242774566475, 0.6231578947368421, 0.36007462686567165, 1.263813542294555, 1, 1, 0.36007462686567165, 1, 1, 0.6231578947368421, 0.6231578947368421, 1, 3.4046242774566475, 0.6231578947368421, 0.36007462686567165, 1, 1, 1, 0.6231578947368421, 0.6231578947368421, 1, 1, 1, 0.6231578947368421, 1.263813542294555, 0.6231578947368421, 3.4046242774566475, 1, 1.263813542294555, 1, 1, 1, 0.6231578947368421, 1, 3.4046242774566475, 0.6231578947368421, 1, 0.6231578947368421, 0.6231578947368421, 0.6231578947368421, 1, 1.263813542294555, 1, 1, 1, 1, 1, 3.4046242774566475, 1.263813542294555, 1, 1.263813542294555, 1, 1, 1, 0.6231578947368421, 1, 0.6231578947368421, 0.6231578947368421, 1, 0.6231578947368421, 1, 1, 1, 1, 1, 1, 1, 1.263813542294555, 0.6231578947368421, 1, 0.6231578947368421, 1, 0.6231578947368421, 1, 1, 1, 1, 1, 1, 1, 0.6231578947368421, 1, 1, 1.263813542294555, 0.36007462686567165, 1, 1, 1, 3.4046242774566475, 1, 0.7102803738317757, 1, 0.6231578947368421, 1, 1, 1.263813542294555, 1, 1, 0.6231578947368421, 1.263813542294555, 1, 1, 1, 0.6231578947368421, 0.6231578947368421, 1, 1, 1.263813542294555, 1.263813542294555, 2.652083333333333, 1, 1, 1, 1.078804347826087, 1.263813542294555, 1, 1, 1.263813542294555, 1, 1.263813542294555, 1.263813542294555, 1, 0.6231578947368421, 1, 1, 1, 1, 1, 1.263813542294555, 1, 0.6231578947368421, 1, 1, 1, 1, 1, 0.36007462686567165, 1, 1.263813542294555, 1, 1.263813542294555, 1, 1.048091603053435, 1.263813542294555, 1.048091603053435, 1, 1, 1, 1, 1, 1, 1, 0.6231578947368421, 1, 0.6231578947368421, 0.6754098360655738, 0.6754098360655738, 0.6754098360655738, 1, 1, 0.6231578947368421, 1, 1, 1.263813542294555, 1.263813542294555, 1, 1, 0.6231578947368421, 1, 1.078804347826087, 1, 0.6231578947368421, 0.6231578947368421, 1, 0.6231578947368421, 1, 1.263813542294555, 1, 0.6231578947368421, 0.6231578947368421, 1, 1, 1, 1, 0.6231578947368421, 0.6231578947368421, 1, 0.6231578947368421, 1, 1, 0.7102803738317757, 1, 1, 1.048091603053435, 0.36007462686567165, 1, 0.6231578947368421, 1, 1, 0.6231578947368421, 1, 0.6231578947368421, 1.263813542294555, 1, 1, 1, 1.263813542294555, 0.6231578947368421, 1, 0.36007462686567165, 1, 1, 1, 1, 0.36007462686567165, 1, 1, 1.048091603053435, 1, 0.6754098360655738, 0.6754098360655738, 0.6231578947368421, 1, 1, 0.36007462686567165, 0.6231578947368421, 1, 1, 0.6231578947368421, 1, 0.6231578947368421, 1, 1, 0.6231578947368421, 1, 3.4046242774566475, 0.36007462686567165, 1, 0.5651041666666666, 1.078804347826087, 1, 1, 1.078804347826087, 1 ...

# %%
## Run OLS regressions, equalizing for pay and weights

merged['log_equal_female_pay'] = merged['equal_pay_female'].apply(math.log10)
merged['log_equal_male_pay'] = merged['equal_pay_male'].apply(math.log10)

print (np.mean(merged[merged['final_gender'] == "female"]['equal_pay_female']))
print (np.mean(merged[merged['final_gender'] == "male"]['equal_pay_female']))

print (np.mean(merged[merged['final_gender'] == "female"]['equal_pay_male']))
print (np.mean(merged[merged['final_gender'] == "male"]['equal_pay_male']))

model = ols("log_equal_female_pay ~ dummy_gender", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print (anova_table)

print (model.params)
# Out:
# 36.0778055856
# 39.8728681108
# 41.4541241644
# 45.6585292703
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     log_equal_female_pay   R-squared:                       0.059
# Model:                              OLS   Adj. R-squared:                  0.059
# Method:                   Least Squares   F-statistic:                     3031.
# Date:                  Thu, 01 Mar 2018   Prob (F-statistic):               0.00
# Time:                          17:05:56   Log-Likelihood:                 44556.
# No. Observations:                 48035   AIC:                        -8.911e+04
# Df Residuals:                     48033   BIC:                        -8.909e+04
# Df Model:                             1
# Covariance Type:              nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        1.5446      0.001   2452.736      0.000       1.543       1.546
# dummy_gender     0.0481      0.001     55.054      0.000       0.046       0.050
# ==============================================================================
# Omnibus:                     1713.055   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1805.834
# Skew:                          -0.454   Prob(JB):                         0.00
# Kurtosis:                       2.724   Cond. No.                         2.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                   sum_sq       df            F  PR(>F)
# dummy_gender   27.762041      1.0  3030.993736     0.0
# Residual      439.952772  48033.0          NaN     NaN
# Intercept       1.544632
# dummy_gender    0.048117
# dtype: float64

# %%
model = ols("log_equal_male_pay ~ dummy_gender", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print (anova_table)

print (model.params)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     log_equal_male_pay   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     2395.
# Date:                Thu, 01 Mar 2018   Prob (F-statistic):               0.00
# Time:                        17:05:56   Log-Likelihood:                 40058.
# No. Observations:               48035   AIC:                        -8.011e+04
# Df Residuals:                   48033   BIC:                        -8.009e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        1.6021      0.001   2316.591      0.000       1.601       1.603
# dummy_gender     0.0470      0.001     48.937      0.000       0.045       0.049
# ==============================================================================
# Omnibus:                      148.379   Durbin-Watson:                   1.879
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              149.695
# Skew:                           0.137   Prob(JB):                     3.12e-33
# Kurtosis:                       3.010   Cond. No.                         2.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                   sum_sq       df            F  PR(>F)
# dummy_gender   26.452924      1.0  2394.792102     0.0
# Residual      530.573535  48033.0          NaN     NaN
# Intercept       1.602113
# dummy_gender    0.046969
# dtype: float64

# %%
from __future__ import print_function
import numpy as np
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from statsmodels.iolib.table import (SimpleTable, default_txt_fmt)

def log_this(row):
    return math.log10(row['bill_rate'])

merged['log_bill_rate'] = merged.apply(log_this, axis=1) # Convert to log of hourly bill rates

mod_wls = sm.WLS(merged.log_bill_rate, merged.dummy_gender, weights=female_weights)
res_wls = mod_wls.fit()
print(res_wls.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.494
# Model:                            WLS   Adj. R-squared:                  0.494
# Method:                 Least Squares   F-statistic:                 4.687e+04
# Date:                Thu, 01 Mar 2018   Prob (F-statistic):               0.00
# Time:                        17:05:57   Log-Likelihood:                -74727.
# No. Observations:               48035   AIC:                         1.495e+05
# Df Residuals:                   48034   BIC:                         1.495e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# dummy_gender     1.4986      0.007    216.495      0.000       1.485       1.512
# ==============================================================================
# Omnibus:                       15.202   Durbin-Watson:                   1.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3991.621
# Skew:                           0.044   Prob(JB):                         0.00
# Kurtosis:                       1.590   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mod_wls = sm.WLS(merged.log_bill_rate, merged.dummy_gender, weights=male_weights)
res_wls = mod_wls.fit()
print(res_wls.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.496
# Model:                            WLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                 4.735e+04
# Date:                Thu, 01 Mar 2018   Prob (F-statistic):               0.00
# Time:                        17:06:15   Log-Likelihood:                -75549.
# No. Observations:               48035   AIC:                         1.511e+05
# Df Residuals:                   48034   BIC:                         1.511e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# dummy_gender     1.5467      0.007    217.607      0.000       1.533       1.561
# ==============================================================================
# Omnibus:                     4577.458   Durbin-Watson:                   1.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5996.651
# Skew:                           0.834   Prob(JB):                         0.00
# Kurtosis:                       3.463   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mod_wls = sm.WLS(merged.log_equal_female_pay, merged.dummy_gender)
res_wls = mod_wls.fit()
print(res_wls.summary())
# Out:
#                              WLS Regression Results
# ================================================================================
# Dep. Variable:     log_equal_female_pay   R-squared:                       0.533
# Model:                              WLS   Adj. R-squared:                  0.533
# Method:                   Least Squares   F-statistic:                 5.472e+04
# Date:                  Thu, 01 Mar 2018   Prob (F-statistic):               0.00
# Time:                          17:06:19   Log-Likelihood:                -71646.
# No. Observations:                 48035   AIC:                         1.433e+05
# Df Residuals:                     48034   BIC:                         1.433e+05
# Df Model:                             1
# Covariance Type:              nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# dummy_gender     1.5927      0.007    233.916      0.000       1.579       1.606
# ==============================================================================
# Omnibus:                       55.869   Durbin-Watson:                   1.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7519.327
# Skew:                           0.084   Prob(JB):                         0.00
# Kurtosis:                       1.069   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mod_wls = sm.WLS(merged.log_equal_male_pay, merged.dummy_gender)
res_wls = mod_wls.fit()
print(res_wls.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     log_equal_male_pay   R-squared:                       0.531
# Model:                            WLS   Adj. R-squared:                  0.531
# Method:                 Least Squares   F-statistic:                 5.447e+04
# Date:                Thu, 01 Mar 2018   Prob (F-statistic):               0.00
# Time:                        17:06:20   Log-Likelihood:                -73424.
# No. Observations:               48035   AIC:                         1.469e+05
# Df Residuals:                   48034   BIC:                         1.469e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# dummy_gender     1.6491      0.007    233.388      0.000       1.635       1.663
# ==============================================================================
# Omnibus:                       56.457   Durbin-Watson:                   1.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7459.913
# Skew:                           0.084   Prob(JB):                         0.00
# Kurtosis:                       1.077   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mod_wls = sm.WLS(merged.bill_rate, merged.dummy_gender, weights=female_weights)
res_wls = mod_wls.fit()
print(res_wls.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              bill_rate   R-squared:                       0.285
# Model:                            WLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                 1.914e+04
# Date:                Thu, 01 Mar 2018   Prob (F-statistic):               0.00
# Time:                        17:06:23   Log-Likelihood:            -2.5571e+05
# No. Observations:               48035   AIC:                         5.114e+05
# Df Residuals:                   48034   BIC:                         5.114e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# dummy_gender    41.4541      0.300    138.353      0.000      40.867      42.041
# ==============================================================================
# Omnibus:                    63193.420   Durbin-Watson:                   1.577
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         39989792.588
# Skew:                           6.998   Prob(JB):                         0.00
# Kurtosis:                     143.657   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mod_wls = sm.WLS(merged.log_bill_rate, merged.dummy_gender, weights=male_weights)
res_wls = mod_wls.fit()
print(res_wls.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.496
# Model:                            WLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                 4.735e+04
# Date:                Thu, 01 Mar 2018   Prob (F-statistic):               0.00
# Time:                        17:06:23   Log-Likelihood:                -75549.
# No. Observations:               48035   AIC:                         1.511e+05
# Df Residuals:                   48034   BIC:                         1.511e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# dummy_gender     1.5467      0.007    217.607      0.000       1.533       1.561
# ==============================================================================
# Omnibus:                     4577.458   Durbin-Watson:                   1.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5996.651
# Skew:                           0.834   Prob(JB):                         0.00
# Kurtosis:                       3.463   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mod_wls = sm.WLS(merged.log_bill_rate, merged.dummy_gender)
res_wls = mod_wls.fit()
print(res_wls.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.528
# Model:                            WLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                 5.377e+04
# Date:                Thu, 01 Mar 2018   Prob (F-statistic):               0.00
# Time:                        17:06:24   Log-Likelihood:                -70655.
# No. Observations:               48035   AIC:                         1.413e+05
# Df Residuals:                   48034   BIC:                         1.413e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# dummy_gender     1.5467      0.007    231.889      0.000       1.534       1.560
# ==============================================================================
# Omnibus:                       11.055   Durbin-Watson:                   1.087
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):             4246.898
# Skew:                           0.037   Prob(JB):                         0.00
# Kurtosis:                       1.545   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Gender Pay Gap within Job Categories
#
# Following Goldin's argument that the majority of the pay gap can be explained by within job gender differences in pay.

# %%
merged['hours_worked'] == merged['hours_worked'].astype('float')

def log_this(row):
    return math.log10(row['bill_rate'])

merged['log_bill_rate'] = merged.apply(log_this, axis=1) # Convert to log of hourly bill rates

model = ols("log_bill_rate ~ final_gender", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     1072.
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          1.33e-232
# Time:                        15:41:22   Log-Likelihood:                -9295.4
# No. Observations:               48035   AIC:                         1.859e+04
# Df Residuals:                   48033   BIC:                         1.861e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4589      0.002    755.042      0.000       1.455       1.463
# final_gender[T.male]     0.0878      0.003     32.745      0.000       0.083       0.093
# ==============================================================================
# Omnibus:                      713.087   Durbin-Watson:                   1.385
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1048.236
# Skew:                           0.173   Prob(JB):                    2.39e-228
# Kurtosis:                       3.635   Cond. No.                         2.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                    sum_sq       df            F         PR(>F)
# final_gender    92.450002      1.0  1072.209666  1.331708e-232
# Residual      4141.588232  48033.0          NaN            NaN
# Intercept               1.458902
# final_gender[T.male]    0.087806
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + hours_worked", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     538.2
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          6.88e-232
# Time:                        15:41:23   Log-Likelihood:                -9293.3
# No. Observations:               48035   AIC:                         1.859e+04
# Df Residuals:                   48032   BIC:                         1.862e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4594      0.002    750.293      0.000       1.456       1.463
# final_gender[T.male]     0.0877      0.003     32.682      0.000       0.082       0.093
# hours_worked         -4.936e-06   2.42e-06     -2.036      0.042   -9.69e-06   -1.85e-07
# ==============================================================================
# Omnibus:                      711.213   Durbin-Watson:                   1.385
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1046.169
# Skew:                           0.173   Prob(JB):                    6.72e-228
# Kurtosis:                       3.635   Cond. No.                     1.29e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                    sum_sq       df            F         PR(>F)
# final_gender    92.088258      1.0  1068.084220  1.003655e-231
# hours_worked     0.357488      1.0     4.146314   4.173074e-02
# Residual      4141.230744  48032.0          NaN            NaN
# Intercept               1.459357
# final_gender[T.male]    0.087664
# hours_worked           -0.000005
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + hours_worked + education", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     464.8
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):               0.00
# Time:                        15:41:24   Log-Likelihood:                -8690.9
# No. Observations:               48035   AIC:                         1.739e+04
# Df Residuals:                   48029   BIC:                         1.745e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  1.4805      0.002    722.934      0.000       1.477       1.485
# final_gender[T.male]                       0.0895      0.003     33.794      0.000       0.084       0.095
# education[T.High School]                  -0.1950      0.008    -24.176      0.000      -0.211      -0.179
# education[T.Less Than High School]        -0.1936      0.011    -18.226      0.000      -0.214      -0.173
# education[T.Some College or Associate]    -0.0711      0.003    -21.108      0.000      -0.078      -0.064
# hours_worked                           -3.518e-06   2.39e-06     -1.469      0.142   -8.21e-06    1.18e-06
# ==============================================================================
# Omnibus:                      885.176   Durbin-Watson:                   1.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1326.708
# Skew:                           0.204   Prob(JB):                    8.11e-289
# Kurtosis:                       3.704   Cond. No.                     4.49e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.49e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                    sum_sq       df            F         PR(>F)
# final_gender    96.028384      1.0  1142.005313  1.980655e-247
# education      102.591711      3.0   406.686282  6.556771e-261
# hours_worked     0.181502      1.0     2.158491   1.417904e-01
# Residual      4038.639033  48029.0          NaN            NaN
# Intercept                                 1.480547
# final_gender[T.male]                      0.089539
# education[T.High School]                 -0.195024
# education[T.Less Than High School]       -0.193595
# education[T.Some College or Associate]   -0.071085
# hours_worked                             -0.000004
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + hours_worked + education + job_category", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     453.5
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):               0.00
# Time:                        15:41:24   Log-Likelihood:                -6445.7
# No. Observations:               48035   AIC:                         1.293e+04
# Df Residuals:                   48018   BIC:                         1.307e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                      1.6453      0.006    297.311      0.000       1.634       1.656
# final_gender[T.male]                           0.0445      0.003     16.591      0.000       0.039       0.050
# education[T.High School]                      -0.1598      0.008    -20.629      0.000      -0.175      -0.145
# education[T.Less Than High School]            -0.1694      0.010    -16.653      0.000      -0.189      -0.149
# education[T.Some College or Associate]        -0.0577      0.003    -17.699      0.000      -0.064      -0.051
# job_category[T.Admin Support]                 -0.2951      0.007    -45.249      0.000      -0.308      -0.282
# job_category[T.Customer Service]              -0.3172      0.010    -32.791      0.000      -0.336      -0.298
# job_category[T.Data Science & Analytics]      -0.0872      0.009    -10.232      0.000      -0.104      -0.070
# job_category[T.Design & Creative]             -0.1374      0.006    -23.004      0.000      -0.149      -0.126
# job_category[T.Engineering & Architecture]    -0.0944      0.009    -10.213      0.000      -0.113      -0.076
# job_category[T.IT & Networking]               -0.0037      0.009     -0.395      0.693      -0.022       0.015
# job_category[T.Legal]                          0.0137      0.015      0.889      0.374      -0.017       0.044
# job_category[T.Sales & Marketing]             -0.0400      0.007     -5.738      0.000      -0.054      -0.026
# job_category[T.Translation]                   -0.2783      0.009    -31.377      0.000      -0.296      -0.261
# job_category[T.Web, Mobile & Software Dev]    -0.0821      0.006    -12.940      0.000      -0.095      -0.070
# job_category[T.Writing]                       -0.1917      0.006    -31.814      0.000      -0.204      -0.180
# hours_worked                                3.819e-08   2.29e-06      0.017      0.987   -4.45e-06    4.53e-06
# ==============================================================================
# Omnibus:                      926.400   Durbin-Watson:                   1.489
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1743.550
# Skew:                           0.127   Prob(JB):                         0.00
# Kurtosis:                       3.898   Cond. No.                     8.86e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.86e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                    sum_sq       df           F         PR(>F)
# final_gender    21.085345      1.0  275.262463   1.202065e-61
# education       68.367014      3.0  297.503199  2.222622e-191
# job_category   360.418307     11.0  427.740564   0.000000e+00
# hours_worked     0.000021      1.0    0.000278   9.867059e-01
# Residual      3678.220726  48018.0         NaN            NaN
# Intercept                                     1.645325e+00
# final_gender[T.male]                          4.453163e-02
# education[T.High School]                     -1.598429e-01
# education[T.Less Than High School]           -1.694211e-01
# education[T.Some College or Associate]       -5.766021e-02
# job_category[T.Admin Support]                -2.951375e-01
# job_category[T.Customer Service]             -3.172114e-01
# job_category[T.Data Science & Analytics]     -8.718691e-02
# job_category[T.Design & Creative]            -1.373912e-01
# job_category[T.Engineering & Architecture]   -9.441233e-02
# job_category[T.IT & Networking]              -3.682653e-03
# job_category[T.Legal]                         1.370970e-02
# job_category[T.Sales & Marketing]            -4.000814e-02
# job_category[T.Translation]                  -2.783245e-01
# job_category[T.Web, Mobile & Software Dev]   -8.214369e-02
# job_category[T.Writing]                      -1.917214e-01
# hours_worked                                  3.819319e-08
# dtype: float64

# %% [markdown]
# ### Even when using number of jobs completed as a proxy for work experience, pay gap is not explained any better

# %%
model = ols("log_bill_rate ~ final_gender + jobs_completed", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     564.2
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          6.41e-243
# Time:                        15:41:25   Log-Likelihood:                -9267.9
# No. Observations:               48035   AIC:                         1.854e+04
# Df Residuals:                   48032   BIC:                         1.857e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4569      0.002    746.948      0.000       1.453       1.461
# final_gender[T.male]     0.0884      0.003     32.962      0.000       0.083       0.094
# jobs_completed           0.0004   4.81e-05      7.415      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                      720.201   Durbin-Watson:                   1.390
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1057.370
# Skew:                           0.175   Prob(JB):                    2.48e-230
# Kurtosis:                       3.637   Cond. No.                         65.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                      sum_sq       df            F         PR(>F)
# final_gender      93.575931      1.0  1086.487426  1.228628e-235
# jobs_completed     4.734918      1.0    54.975980   1.240153e-13
# Residual        4136.853314  48032.0          NaN            NaN
# Intercept               1.456872
# final_gender[T.male]    0.088376
# jobs_completed          0.000357
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + jobs_completed + education", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     475.4
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):               0.00
# Time:                        15:41:26   Log-Likelihood:                -8665.5
# No. Observations:               48035   AIC:                         1.734e+04
# Df Residuals:                   48029   BIC:                         1.740e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  1.4783      0.002    719.645      0.000       1.474       1.482
# final_gender[T.male]                       0.0902      0.003     34.055      0.000       0.085       0.095
# education[T.High School]                  -0.1948      0.008    -24.159      0.000      -0.211      -0.179
# education[T.Less Than High School]        -0.1926      0.011    -18.142      0.000      -0.213      -0.172
# education[T.Some College or Associate]    -0.0713      0.003    -21.201      0.000      -0.078      -0.065
# jobs_completed                             0.0003   4.76e-05      7.273      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                      894.729   Durbin-Watson:                   1.415
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1339.719
# Skew:                           0.207   Prob(JB):                    1.21e-291
# Kurtosis:                       3.706   Cond. No.                         227.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                      sum_sq       df            F         PR(>F)
# final_gender      97.418201      1.0  1159.757402  3.380141e-251
# education        102.476164      3.0   406.657375  6.839749e-261
# jobs_completed     4.443385      1.0    52.898212   3.566341e-13
# Residual        4034.377150  48029.0          NaN            NaN
# Intercept                                 1.478285
# final_gender[T.male]                      0.090190
# education[T.High School]                 -0.194757
# education[T.Less Than High School]       -0.192610
# education[T.Some College or Associate]   -0.071348
# jobs_completed                            0.000346
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + jobs_completed + education + job_category", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     458.5
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):               0.00
# Time:                        15:41:27   Log-Likelihood:                -6410.7
# No. Observations:               48035   AIC:                         1.286e+04
# Df Residuals:                   48018   BIC:                         1.300e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                      1.6442      0.006    297.460      0.000       1.633       1.655
# final_gender[T.male]                           0.0449      0.003     16.728      0.000       0.040       0.050
# education[T.High School]                      -0.1596      0.008    -20.614      0.000      -0.175      -0.144
# education[T.Less Than High School]            -0.1687      0.010    -16.596      0.000      -0.189      -0.149
# education[T.Some College or Associate]        -0.0580      0.003    -17.825      0.000      -0.064      -0.052
# job_category[T.Admin Support]                 -0.2953      0.007    -45.316      0.000      -0.308      -0.283
# job_category[T.Customer Service]              -0.3173      0.010    -32.849      0.000      -0.336      -0.298
# job_category[T.Data Science & Analytics]      -0.0872      0.009    -10.242      0.000      -0.104      -0.071
# job_category[T.Design & Creative]             -0.1379      0.006    -23.108      0.000      -0.150      -0.126
# job_category[T.Engineering & Architecture]    -0.0943      0.009    -10.207      0.000      -0.112      -0.076
# job_category[T.IT & Networking]               -0.0036      0.009     -0.389      0.697      -0.022       0.015
# job_category[T.Legal]                          0.0100      0.015      0.646      0.518      -0.020       0.040
# job_category[T.Sales & Marketing]             -0.0413      0.007     -5.928      0.000      -0.055      -0.028
# job_category[T.Translation]                   -0.2791      0.009    -31.493      0.000      -0.297      -0.262
# job_category[T.Web, Mobile & Software Dev]    -0.0824      0.006    -12.982      0.000      -0.095      -0.070
# job_category[T.Writing]                       -0.1941      0.006    -32.191      0.000      -0.206      -0.182
# jobs_completed                                 0.0004   4.55e-05      8.372      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                      933.729   Durbin-Watson:                   1.494
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1758.298
# Skew:                           0.129   Prob(JB):                         0.00
# Kurtosis:                       3.901   Cond. No.                         448.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                      sum_sq       df           F         PR(>F)
# final_gender      21.404618      1.0  279.838308   1.225948e-62
# education         68.383980      3.0  298.011347  1.052557e-191
# job_category     361.517074     11.0  429.670771   0.000000e+00
# jobs_completed     5.360670      1.0   70.083984   5.834545e-17
# Residual        3672.860077  48018.0         NaN            NaN
# Intercept                                     1.644169
# final_gender[T.male]                          0.044866
# education[T.High School]                     -0.159597
# education[T.Less Than High School]           -0.168718
# education[T.Some College or Associate]       -0.058026
# job_category[T.Admin Support]                -0.295348
# job_category[T.Customer Service]             -0.317261
# job_category[T.Data Science & Analytics]     -0.087210
# job_category[T.Design & Creative]            -0.137887
# job_category[T.Engineering & Architecture]   -0.094283
# job_category[T.IT & Networking]              -0.003619
# job_category[T.Legal]                         0.009965
# job_category[T.Sales & Marketing]            -0.041313
# job_category[T.Translation]                  -0.279138
# job_category[T.Web, Mobile & Software Dev]   -0.082350
# job_category[T.Writing]                      -0.194061
# jobs_completed                                0.000381
# dtype: float64

# %% [markdown]
# ### Using work experience in years a proxy for work experience

# %%
model = ols("log_bill_rate ~ final_gender + work_experience", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     1513.
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):               0.00
# Time:                        15:41:28   Log-Likelihood:                -8358.5
# No. Observations:               48035   AIC:                         1.672e+04
# Df Residuals:                   48032   BIC:                         1.675e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4127      0.002    651.021      0.000       1.408       1.417
# final_gender[T.male]     0.0888      0.003     33.774      0.000       0.084       0.094
# work_experience          0.0085      0.000     43.711      0.000       0.008       0.009
# ==============================================================================
# Omnibus:                      897.979   Durbin-Watson:                   1.424
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1373.915
# Skew:                           0.200   Prob(JB):                    4.55e-299
# Kurtosis:                       3.725   Cond. No.                         20.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                       sum_sq       df            F         PR(>F)
# final_gender       94.595338      1.0  1140.707660  3.733465e-247
# work_experience   158.443867      1.0  1910.645242   0.000000e+00
# Residual         3983.144364  48032.0          NaN            NaN
# Intercept               1.412684
# final_gender[T.male]    0.088823
# work_experience         0.008456
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + work_experience + education", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     851.7
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):               0.00
# Time:                        15:41:29   Log-Likelihood:                -7785.3
# No. Observations:               48035   AIC:                         1.558e+04
# Df Residuals:                   48029   BIC:                         1.564e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  1.4347      0.002    633.926      0.000       1.430       1.439
# final_gender[T.male]                       0.0905      0.003     34.832      0.000       0.085       0.096
# education[T.High School]                  -0.1879      0.008    -23.732      0.000      -0.203      -0.172
# education[T.Less Than High School]        -0.1746      0.010    -16.739      0.000      -0.195      -0.154
# education[T.Some College or Associate]    -0.0704      0.003    -21.301      0.000      -0.077      -0.064
# work_experience                            0.0082      0.000     42.985      0.000       0.008       0.009
# ==============================================================================
# Omnibus:                     1107.197   Durbin-Watson:                   1.447
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1740.161
# Skew:                           0.233   Prob(JB):                         0.00
# Kurtosis:                       3.808   Cond. No.                         70.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                       sum_sq       df            F         PR(>F)
# final_gender       98.243809      1.0  1213.245240  1.529926e-262
# education          93.945574      3.0   386.721639  3.143160e-248
# work_experience   149.621745      1.0  1847.728336   0.000000e+00
# Residual         3889.198790  48029.0          NaN            NaN
# Intercept                                 1.434672
# final_gender[T.male]                      0.090538
# education[T.High School]                 -0.187883
# education[T.Less Than High School]       -0.174631
# education[T.Some College or Associate]   -0.070382
# work_experience                           0.008227
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + work_experience + education + job_category", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.168
# Model:                            OLS   Adj. R-squared:                  0.168
# Method:                 Least Squares   F-statistic:                     606.6
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):               0.00
# Time:                        15:41:30   Log-Likelihood:                -5404.4
# No. Observations:               48035   AIC:                         1.084e+04
# Df Residuals:                   48018   BIC:                         1.099e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                      1.5841      0.006    284.330      0.000       1.573       1.595
# final_gender[T.male]                           0.0423      0.003     16.090      0.000       0.037       0.047
# education[T.High School]                      -0.1538      0.008    -20.276      0.000      -0.169      -0.139
# education[T.Less Than High School]            -0.1522      0.010    -15.280      0.000      -0.172      -0.133
# education[T.Some College or Associate]        -0.0580      0.003    -18.199      0.000      -0.064      -0.052
# job_category[T.Admin Support]                 -0.2839      0.006    -44.448      0.000      -0.296      -0.271
# job_category[T.Customer Service]              -0.3053      0.009    -32.262      0.000      -0.324      -0.287
# job_category[T.Data Science & Analytics]      -0.0647      0.008     -7.751      0.000      -0.081      -0.048
# job_category[T.Design & Creative]             -0.1133      0.006    -19.320      0.000      -0.125      -0.102
# job_category[T.Engineering & Architecture]    -0.0756      0.009     -8.344      0.000      -0.093      -0.058
# job_category[T.IT & Networking]                0.0124      0.009      1.359      0.174      -0.005       0.030
# job_category[T.Legal]                          0.0143      0.015      0.945      0.345      -0.015       0.044
# job_category[T.Sales & Marketing]             -0.0264      0.007     -3.861      0.000      -0.040      -0.013
# job_category[T.Translation]                   -0.2508      0.009    -28.826      0.000      -0.268      -0.234
# job_category[T.Web, Mobile & Software Dev]    -0.0580      0.006     -9.309      0.000      -0.070      -0.046
# job_category[T.Writing]                       -0.1837      0.006    -31.137      0.000      -0.195      -0.172
# work_experience                                0.0085      0.000     46.126      0.000       0.008       0.009
# ==============================================================================
# Omnibus:                     1226.897   Durbin-Watson:                   1.530
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2459.803
# Skew:                           0.169   Prob(JB):                         0.00
# Kurtosis:                       4.056   Cond. No.                         139.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                       sum_sq       df            F         PR(>F)
# final_gender       18.990072      1.0   258.894034   4.243929e-58
# education          62.740093      3.0   285.114520  1.836796e-183
# job_category      367.042417     11.0   454.903214   0.000000e+00
# work_experience   156.064374      1.0  2127.645208   0.000000e+00
# Residual         3522.156373  48018.0          NaN            NaN
# Intercept                                     1.584118
# final_gender[T.male]                          0.042263
# education[T.High School]                     -0.153750
# education[T.Less Than High School]           -0.152219
# education[T.Some College or Associate]       -0.058009
# job_category[T.Admin Support]                -0.283888
# job_category[T.Customer Service]             -0.305250
# job_category[T.Data Science & Analytics]     -0.064739
# job_category[T.Design & Creative]            -0.113336
# job_category[T.Engineering & Architecture]   -0.075561
# job_category[T.IT & Networking]               0.012400
# job_category[T.Legal]                         0.014270
# job_category[T.Sales & Marketing]            -0.026365
# job_category[T.Translation]                  -0.250776
# job_category[T.Web, Mobile & Software Dev]   -0.058028
# job_category[T.Writing]                      -0.183693
# work_experience                               0.008480
# dtype: float64

# %% [markdown]
# ### When all covariates are added, gender pay gap is not explained better

# %%
model = ols("log_bill_rate ~ final_gender + jobs_completed + work_experience + hours_worked + job_category + education", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.168
# Method:                 Least Squares   F-statistic:                     541.5
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):               0.00
# Time:                        15:41:31   Log-Likelihood:                -5386.8
# No. Observations:               48035   AIC:                         1.081e+04
# Df Residuals:                   48016   BIC:                         1.098e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                      1.5847      0.006    284.487      0.000       1.574       1.596
# final_gender[T.male]                           0.0422      0.003     16.062      0.000       0.037       0.047
# job_category[T.Admin Support]                 -0.2836      0.006    -44.417      0.000      -0.296      -0.271
# job_category[T.Customer Service]              -0.3031      0.009    -32.018      0.000      -0.322      -0.285
# job_category[T.Data Science & Analytics]      -0.0650      0.008     -7.781      0.000      -0.081      -0.049
# job_category[T.Design & Creative]             -0.1143      0.006    -19.480      0.000      -0.126      -0.103
# job_category[T.Engineering & Architecture]    -0.0760      0.009     -8.394      0.000      -0.094      -0.058
# job_category[T.IT & Networking]                0.0122      0.009      1.340      0.180      -0.006       0.030
# job_category[T.Legal]                          0.0121      0.015      0.799      0.424      -0.018       0.042
# job_category[T.Sales & Marketing]             -0.0268      0.007     -3.930      0.000      -0.040      -0.013
# job_category[T.Translation]                   -0.2518      0.009    -28.947      0.000      -0.269      -0.235
# job_category[T.Web, Mobile & Software Dev]    -0.0582      0.006     -9.341      0.000      -0.070      -0.046
# job_category[T.Writing]                       -0.1850      0.006    -31.327      0.000      -0.197      -0.173
# education[T.High School]                      -0.1531      0.008    -20.192      0.000      -0.168      -0.138
# education[T.Less Than High School]            -0.1523      0.010    -15.292      0.000      -0.172      -0.133
# education[T.Some College or Associate]        -0.0579      0.003    -18.169      0.000      -0.064      -0.052
# jobs_completed                                 0.0002   4.62e-05      3.958      0.000    9.23e-05       0.000
# work_experience                                0.0085      0.000     45.682      0.000       0.008       0.009
# hours_worked                                -1.21e-05   2.32e-06     -5.226      0.000   -1.66e-05   -7.56e-06
# ==============================================================================
# Omnibus:                     1224.574   Durbin-Watson:                   1.532
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2458.455
# Skew:                           0.168   Prob(JB):                         0.00
# Kurtosis:                       4.056   Cond. No.                     8.88e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                       sum_sq       df            F         PR(>F)
# final_gender       18.910031      1.0   257.981435   6.693276e-58
# job_category      366.011683     11.0   453.940026   0.000000e+00
# education          62.429052      3.0   283.897588  1.101874e-182
# jobs_completed      1.148318      1.0    15.666008   7.567889e-05
# work_experience   152.962537      1.0  2086.802241   0.000000e+00
# hours_worked        2.001727      1.0    27.308700   1.741526e-07
# Residual         3519.571262  48016.0          NaN            NaN
# Intercept                                     1.584715
# final_gender[T.male]                          0.042185
# job_category[T.Admin Support]                -0.283626
# job_category[T.Customer Service]             -0.303143
# job_category[T.Data Science & Analytics]     -0.064965
# job_category[T.Design & Creative]            -0.114284
# job_category[T.Engineering & Architecture]   -0.075982
# job_category[T.IT & Networking]               0.012216
# job_category[T.Legal]                         0.012059
# job_category[T.Sales & Marketing]            -0.026841
# job_category[T.Translation]                  -0.251811
# job_category[T.Web, Mobile & Software Dev]   -0.058216
# job_category[T.Writing]                      -0.185009
# education[T.High School]                     -0.153081
# education[T.Less Than High School]           -0.152290
# education[T.Some College or Associate]       -0.057905
# jobs_completed                                0.000183
# work_experience                               0.008481
# hours_worked                                 -0.000012
# dtype: float64

# %% [markdown]
# ### Same analyses, but only including workers with at least some work experience on Upwork

# %%
merged_have_worked = merged[merged['hours_worked'] > 0]

model = ols("log_bill_rate ~ final_gender", merged_have_worked).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     464.1
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          1.59e-100
# Time:                        15:41:31   Log-Likelihood:                -1270.3
# No. Observations:                9444   AIC:                             2545.
# Df Residuals:                    9442   BIC:                             2559.
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4576      0.004    366.426      0.000       1.450       1.465
# final_gender[T.male]     0.1228      0.006     21.543      0.000       0.112       0.134
# ==============================================================================
# Omnibus:                      105.350   Durbin-Watson:                   1.279
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              158.628
# Skew:                           0.115   Prob(JB):                     3.58e-35
# Kurtosis:                       3.592   Cond. No.                         2.59
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                   sum_sq      df           F         PR(>F)
# final_gender   35.566979     1.0  464.088458  1.588355e-100
# Residual      723.619409  9442.0         NaN            NaN
# Intercept               1.457647
# final_gender[T.male]    0.122777
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + hours_worked", merged_have_worked).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     239.7
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          2.80e-102
# Time:                        15:41:32   Log-Likelihood:                -1262.9
# No. Observations:                9444   AIC:                             2532.
# Df Residuals:                    9441   BIC:                             2553.
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4617      0.004    355.553      0.000       1.454       1.470
# final_gender[T.male]     0.1219      0.006     21.387      0.000       0.111       0.133
# hours_worked         -9.127e-06   2.38e-06     -3.832      0.000   -1.38e-05   -4.46e-06
# ==============================================================================
# Omnibus:                      104.795   Durbin-Watson:                   1.280
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              158.811
# Skew:                           0.112   Prob(JB):                     3.27e-35
# Kurtosis:                       3.595   Cond. No.                     2.88e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                   sum_sq      df           F        PR(>F)
# final_gender   35.004382     1.0  457.409372  3.864029e-99
# hours_worked    1.123557     1.0   14.681747  1.280979e-04
# Residual      722.495852  9441.0         NaN           NaN
# Intercept               1.461663
# final_gender[T.male]    0.121901
# hours_worked           -0.000009
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + hours_worked + education", merged_have_worked).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     135.3
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          6.13e-139
# Time:                        15:41:32   Log-Likelihood:                -1170.0
# No. Observations:                9444   AIC:                             2352.
# Df Residuals:                    9438   BIC:                             2395.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  1.4770      0.004    344.360      0.000       1.469       1.485
# final_gender[T.male]                       0.1240      0.006     21.959      0.000       0.113       0.135
# education[T.High School]                  -0.1943      0.020     -9.756      0.000      -0.233      -0.155
# education[T.Less Than High School]        -0.1830      0.031     -5.830      0.000      -0.244      -0.121
# education[T.Some College or Associate]    -0.0632      0.007     -8.693      0.000      -0.077      -0.049
# hours_worked                           -6.796e-06   2.37e-06     -2.872      0.004   -1.14e-05   -2.16e-06
# ==============================================================================
# Omnibus:                      116.073   Durbin-Watson:                   1.301
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.551
# Skew:                           0.127   Prob(JB):                     4.60e-39
# Kurtosis:                       3.620   Cond. No.                     1.40e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                   sum_sq      df           F         PR(>F)
# final_gender   36.194940     1.0  482.210369  2.797600e-104
# education      14.075070     3.0   62.505463   5.212876e-40
# hours_worked    0.619001     1.0    8.246698   4.091710e-03
# Residual      708.420782  9438.0         NaN            NaN
# Intercept                                 1.477030
# final_gender[T.male]                      0.124013
# education[T.High School]                 -0.194322
# education[T.Less Than High School]       -0.182953
# education[T.Some College or Associate]   -0.063186
# hours_worked                             -0.000007
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + hours_worked + education + job_category", merged_have_worked).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.155
# Model:                            OLS   Adj. R-squared:                  0.154
# Method:                 Least Squares   F-statistic:                     108.3
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):               0.00
# Time:                        15:41:32   Log-Likelihood:                -699.74
# No. Observations:                9444   AIC:                             1433.
# Df Residuals:                    9427   BIC:                             1555.
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                      1.5912      0.013    126.134      0.000       1.566       1.616
# final_gender[T.male]                           0.0742      0.006     12.908      0.000       0.063       0.085
# education[T.High School]                      -0.1527      0.019     -7.997      0.000      -0.190      -0.115
# education[T.Less Than High School]            -0.1454      0.030     -4.854      0.000      -0.204      -0.087
# education[T.Some College or Associate]        -0.0575      0.007     -8.226      0.000      -0.071      -0.044
# job_category[T.Admin Support]                 -0.2424      0.015    -16.454      0.000      -0.271      -0.213
# job_category[T.Customer Service]              -0.2787      0.020    -13.662      0.000      -0.319      -0.239
# job_category[T.Data Science & Analytics]      -0.0222      0.019     -1.155      0.248      -0.060       0.015
# job_category[T.Design & Creative]             -0.0828      0.014     -5.978      0.000      -0.110      -0.056
# job_category[T.Engineering & Architecture]    -0.0330      0.022     -1.530      0.126      -0.075       0.009
# job_category[T.IT & Networking]                0.0622      0.021      2.931      0.003       0.021       0.104
# job_category[T.Legal]                          0.1381      0.027      5.035      0.000       0.084       0.192
# job_category[T.Sales & Marketing]             -0.0101      0.015     -0.677      0.498      -0.039       0.019
# job_category[T.Translation]                   -0.2443      0.022    -11.022      0.000      -0.288      -0.201
# job_category[T.Web, Mobile & Software Dev]    -0.0128      0.014     -0.887      0.375      -0.041       0.016
# job_category[T.Writing]                       -0.1310      0.013     -9.886      0.000      -0.157      -0.105
# hours_worked                               -2.426e-06   2.28e-06     -1.063      0.288    -6.9e-06    2.05e-06
# ==============================================================================
# Omnibus:                      147.981   Durbin-Watson:                   1.366
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              266.348
# Skew:                           0.095   Prob(JB):                     1.46e-58
# Kurtosis:                       3.801   Cond. No.                     2.10e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.1e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                   sum_sq      df           F         PR(>F)
# final_gender   11.334834     1.0  166.628955   8.420420e-38
# education       9.499598     3.0   46.549959   7.450923e-30
# job_category   67.154827    11.0   89.746986  2.179233e-194
# hours_worked    0.076809     1.0    1.129135   2.879872e-01
# Residual      641.265955  9427.0         NaN            NaN
# Intercept                                     1.591188
# final_gender[T.male]                          0.074221
# education[T.High School]                     -0.152707
# education[T.Less Than High School]           -0.145404
# education[T.Some College or Associate]       -0.057499
# job_category[T.Admin Support]                -0.242368
# job_category[T.Customer Service]             -0.278689
# job_category[T.Data Science & Analytics]     -0.022198
# job_category[T.Design & Creative]            -0.082770
# job_category[T.Engineering & Architecture]   -0.032974
# job_category[T.IT & Networking]               0.062231
# job_category[T.Legal]                         0.138136
# job_category[T.Sales & Marketing]            -0.010077
# job_category[T.Translation]                  -0.244268
# job_category[T.Web, Mobile & Software Dev]   -0.012839
# job_category[T.Writing]                      -0.130954
# hours_worked                                 -0.000002
# dtype: float64

# %% [markdown]
# ### Using number of jobs worked as a proxy for time working

# %%
model = ols("log_bill_rate ~ final_gender + jobs_completed", merged_have_worked).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     254.6
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          2.04e-108
# Time:                        15:41:32   Log-Likelihood:                -1248.8
# No. Observations:                9444   AIC:                             2504.
# Df Residuals:                    9441   BIC:                             2525.
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4497      0.004    349.446      0.000       1.442       1.458
# final_gender[T.male]     0.1244      0.006     21.850      0.000       0.113       0.136
# jobs_completed           0.0003   4.89e-05      6.560      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                      103.764   Durbin-Watson:                   1.295
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              154.827
# Skew:                           0.117   Prob(JB):                     2.40e-34
# Kurtosis:                       3.582   Cond. No.                         143.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                     sum_sq      df           F         PR(>F)
# final_gender     36.426305     1.0  477.417208  2.744893e-103
# jobs_completed    3.283534     1.0   43.035265   5.658323e-11
# Residual        720.335875  9441.0         NaN            NaN
# Intercept               1.449729
# final_gender[T.male]    0.124364
# jobs_completed          0.000321
# dtype: float64

# %% [markdown]
# ### Using work experience as a proxy for time working

# %%
model = ols("log_bill_rate ~ final_gender + work_experience", merged_have_worked).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     384.1
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          4.20e-161
# Time:                        15:41:33   Log-Likelihood:                -1127.4
# No. Observations:                9444   AIC:                             2261.
# Df Residuals:                    9441   BIC:                             2282.
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4086      0.005    289.747      0.000       1.399       1.418
# final_gender[T.male]     0.1215      0.006     21.635      0.000       0.110       0.132
# work_experience          0.0063      0.000     17.027      0.000       0.006       0.007
# ==============================================================================
# Omnibus:                      103.960   Durbin-Watson:                   1.316
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              152.691
# Skew:                           0.123   Prob(JB):                     6.98e-34
# Kurtosis:                       3.572   Cond. No.                         25.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                      sum_sq      df           F         PR(>F)
# final_gender      34.807619     1.0  468.078328  2.364840e-101
# work_experience   21.560127     1.0  289.931582   4.627931e-64
# Residual         702.059282  9441.0         NaN            NaN
# Intercept               1.408648
# final_gender[T.male]    0.121471
# work_experience         0.006308
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + work_experience + education", merged_have_worked).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.094
# Model:                            OLS   Adj. R-squared:                  0.094
# Method:                 Least Squares   F-statistic:                     196.9
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          2.84e-200
# Time:                        15:41:33   Log-Likelihood:                -1028.2
# No. Observations:                9444   AIC:                             2068.
# Df Residuals:                    9438   BIC:                             2111.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  1.4255      0.005    285.003      0.000       1.416       1.435
# final_gender[T.male]                       0.1234      0.006     22.204      0.000       0.113       0.134
# education[T.High School]                  -0.1983      0.020    -10.125      0.000      -0.237      -0.160
# education[T.Less Than High School]        -0.1695      0.031     -5.480      0.000      -0.230      -0.109
# education[T.Some College or Associate]    -0.0662      0.007     -9.262      0.000      -0.080      -0.052
# work_experience                            0.0063      0.000     17.213      0.000       0.006       0.007
# ==============================================================================
# Omnibus:                      118.796   Durbin-Watson:                   1.338
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.941
# Skew:                           0.141   Prob(JB):                     6.24e-39
# Kurtosis:                       3.607   Cond. No.                         122.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                      sum_sq      df           F         PR(>F)
# final_gender      35.911489     1.0  493.022853  1.620581e-106
# education         14.601018     3.0   66.818315   9.509095e-43
# work_experience   21.581519     1.0  296.289086   2.099980e-65
# Residual         687.458264  9438.0         NaN            NaN
# Intercept                                 1.425501
# final_gender[T.male]                      0.123427
# education[T.High School]                 -0.198292
# education[T.Less Than High School]       -0.169463
# education[T.Some College or Associate]   -0.066229
# work_experience                           0.006314
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + work_experience + education + job_category", merged_have_worked).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.184
# Model:                            OLS   Adj. R-squared:                  0.182
# Method:                 Least Squares   F-statistic:                     132.6
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):               0.00
# Time:                        15:41:33   Log-Likelihood:                -538.11
# No. Observations:                9444   AIC:                             1110.
# Df Residuals:                    9427   BIC:                             1232.
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                      1.5264      0.013    119.005      0.000       1.501       1.552
# final_gender[T.male]                           0.0714      0.006     12.630      0.000       0.060       0.082
# education[T.High School]                      -0.1545      0.019     -8.237      0.000      -0.191      -0.118
# education[T.Less Than High School]            -0.1326      0.029     -4.500      0.000      -0.190      -0.075
# education[T.Some College or Associate]        -0.0603      0.007     -8.775      0.000      -0.074      -0.047
# job_category[T.Admin Support]                 -0.2299      0.014    -15.865      0.000      -0.258      -0.202
# job_category[T.Customer Service]              -0.2637      0.020    -13.173      0.000      -0.303      -0.224
# job_category[T.Data Science & Analytics]       0.0002      0.019      0.010      0.992      -0.037       0.037
# job_category[T.Design & Creative]             -0.0641      0.014     -4.704      0.000      -0.091      -0.037
# job_category[T.Engineering & Architecture]    -0.0175      0.021     -0.824      0.410      -0.059       0.024
# job_category[T.IT & Networking]                0.0769      0.021      3.682      0.000       0.036       0.118
# job_category[T.Legal]                          0.1350      0.027      5.008      0.000       0.082       0.188
# job_category[T.Sales & Marketing]              0.0072      0.015      0.492      0.623      -0.022       0.036
# job_category[T.Translation]                   -0.2222      0.022    -10.189      0.000      -0.265      -0.179
# job_category[T.Web, Mobile & Software Dev]     0.0088      0.014      0.614      0.539      -0.019       0.037
# job_category[T.Writing]                       -0.1171      0.013     -8.987      0.000      -0.143      -0.092
# work_experience                                0.0064      0.000     18.150      0.000       0.006       0.007
# ==============================================================================
# Omnibus:                      160.582   Durbin-Watson:                   1.408
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              284.997
# Skew:                           0.121   Prob(JB):                     1.30e-62
# Kurtosis:                       3.816   Cond. No.                         184.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                      sum_sq      df           F         PR(>F)
# final_gender      10.485451     1.0  159.509818   2.845481e-36
# education          9.786782     3.0   49.627105   8.153514e-32
# job_category      67.770082    11.0   93.722878  6.855284e-203
# work_experience   21.654582     1.0  329.420102   2.177678e-72
# Residual         619.688182  9427.0         NaN            NaN
# Intercept                                     1.526438
# final_gender[T.male]                          0.071381
# education[T.High School]                     -0.154468
# education[T.Less Than High School]           -0.132553
# education[T.Some College or Associate]       -0.060250
# job_category[T.Admin Support]                -0.229946
# job_category[T.Customer Service]             -0.263668
# job_category[T.Data Science & Analytics]      0.000189
# job_category[T.Design & Creative]            -0.064098
# job_category[T.Engineering & Architecture]   -0.017463
# job_category[T.IT & Networking]               0.076905
# job_category[T.Legal]                         0.134994
# job_category[T.Sales & Marketing]             0.007207
# job_category[T.Translation]                  -0.222243
# job_category[T.Web, Mobile & Software Dev]    0.008776
# job_category[T.Writing]                      -0.117096
# work_experience                               0.006360
# dtype: float64

# %% [markdown]
# ### Only including workers who have completed at least 1 job

# %%
merged_one_job = merged[merged['jobs_completed'] > 0]

model = ols("log_bill_rate ~ final_gender", merged_one_job).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     531.8
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          1.92e-115
# Time:                        15:41:33   Log-Likelihood:                -2063.6
# No. Observations:               13565   AIC:                             4131.
# Df Residuals:                   13563   BIC:                             4146.
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4585      0.003    427.228      0.000       1.452       1.465
# final_gender[T.male]     0.1116      0.005     23.060      0.000       0.102       0.121
# ==============================================================================
# Omnibus:                      167.461   Durbin-Watson:                   1.322
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              266.057
# Skew:                           0.111   Prob(JB):                     1.68e-58
# Kurtosis:                       3.649   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                    sum_sq       df           F         PR(>F)
# final_gender    42.212301      1.0  531.756307  1.919955e-115
# Residual      1076.668825  13563.0         NaN            NaN
# Intercept               1.458539
# final_gender[T.male]    0.111569
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + hours_worked", merged_one_job).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     271.4
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          2.64e-116
# Time:                        15:41:33   Log-Likelihood:                -2058.3
# No. Observations:               13565   AIC:                             4123.
# Df Residuals:                   13562   BIC:                             4145.
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4610      0.003    418.211      0.000       1.454       1.468
# final_gender[T.male]     0.1110      0.005     22.924      0.000       0.101       0.120
# hours_worked         -7.805e-06   2.39e-06     -3.271      0.001   -1.25e-05   -3.13e-06
# ==============================================================================
# Omnibus:                      166.854   Durbin-Watson:                   1.322
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              266.266
# Skew:                           0.108   Prob(JB):                     1.52e-58
# Kurtosis:                       3.651   Cond. No.                     2.41e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.41e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                    sum_sq       df           F         PR(>F)
# final_gender    41.686918      1.0  525.513552  3.896264e-114
# hours_worked     0.848835      1.0   10.700585   1.073691e-03
# Residual      1075.819989  13562.0         NaN            NaN
# Intercept               1.460980
# final_gender[T.male]    0.110956
# hours_worked           -0.000008
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + jobs_completed", merged_one_job).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     288.7
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          1.58e-123
# Time:                        15:41:34   Log-Likelihood:                -2041.6
# No. Observations:               13565   AIC:                             4089.
# Df Residuals:                   13562   BIC:                             4112.
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4524      0.004    411.175      0.000       1.445       1.459
# final_gender[T.male]     0.1129      0.005     23.352      0.000       0.103       0.122
# jobs_completed           0.0003   4.81e-05      6.636      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                      166.921   Durbin-Watson:                   1.335
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              263.281
# Skew:                           0.113   Prob(JB):                     6.75e-58
# Kurtosis:                       3.644   Cond. No.                         122.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                      sum_sq       df           F         PR(>F)
# final_gender      43.151194      1.0  545.308506  2.804044e-118
# jobs_completed     3.484584      1.0   44.035246   3.347637e-11
# Residual        1073.184240  13562.0         NaN            NaN
# Intercept               1.452389
# final_gender[T.male]    0.112900
# jobs_completed          0.000319
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + work_experience", merged_one_job).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     490.4
# Date:                Tue, 27 Feb 2018   Prob (F-statistic):          2.44e-206
# Time:                        15:41:34   Log-Likelihood:                -1850.9
# No. Observations:               13565   AIC:                             3708.
# Df Residuals:                   13562   BIC:                             3730.
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4095      0.004    343.354      0.000       1.401       1.418
# final_gender[T.male]     0.1110      0.005     23.304      0.000       0.102       0.120
# work_experience          0.0066      0.000     20.786      0.000       0.006       0.007
# ==============================================================================
# Omnibus:                      179.032   Durbin-Watson:                   1.363
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              278.235
# Skew:                           0.131   Prob(JB):                     3.82e-61
# Kurtosis:                       3.650   Cond. No.                         24.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                       sum_sq       df           F         PR(>F)
# final_gender       41.783081      1.0  543.077902  8.209574e-118
# work_experience    33.241825      1.0  432.062458   1.707219e-94
# Residual         1043.426999  13562.0         NaN            NaN
# Intercept               1.409540
# final_gender[T.male]    0.111002
# work_experience         0.006639
# dtype: float64

# %% [markdown]
# ## Across different job categories, what is the relationship between hours worked and hourly bill rate?

# %%
# Change this into a function 
merged_legal = merged[(merged['job_category'] == 'Legal') & (merged['hours_worked'] > 0)]

merged_legal

merged_legal.plot(kind='scatter', x='bill_rate', y='hours_worked', figsize=(15, 10), s=100)

merged_legal_df = merged_legal[['bill_rate', 'hours_worked']]
merged_legal_df.corr(method='pearson')
# Out:
#               bill_rate  hours_worked
# bill_rate      1.000000     -0.055841
# hours_worked  -0.055841      1.000000

# %%
# Change this into a function 
merged_legal = merged[(merged['job_category'] == 'Legal')]

merged_legal

merged_legal.plot(kind='scatter', x='bill_rate', y='hours_worked', figsize=(15, 10), s=100)

merged_legal_df = merged_legal[['bill_rate', 'hours_worked']]
merged_legal_df.corr(method='pearson')
# Out:
#               bill_rate  hours_worked
# bill_rate      1.000000      0.018748
# hours_worked   0.018748      1.000000

# %%
# Change this into a function 
merged_legal = merged[(merged['job_category'] == 'Legal')]

merged_legal

merged_legal.plot(kind='scatter', x='work_experience', y='bill_rate', figsize=(15, 10), s=100)

merged_legal_df = merged_legal[['bill_rate', 'work_experience']]
merged_legal_df.corr(method='pearson')
# Out:
#                  bill_rate  work_experience
# bill_rate         1.000000         0.290835
# work_experience   0.290835         1.000000

# %%
merged_admin = merged[(merged['job_category'] == 'Admin Support') & (merged['hours_worked'] > 0)]

merged_admin

merged_admin.plot(kind='scatter', x='bill_rate', y='hours_worked', figsize=(15, 10), s=100)

merged_admin_df = merged_admin[['bill_rate', 'hours_worked']]
merged_admin_df.corr(method='pearson')
# Out:
#               bill_rate  hours_worked
# bill_rate      1.000000     -0.055185
# hours_worked  -0.055185      1.000000

# %%
merged_admin = merged[(merged['job_category'] == 'Admin Support')]

merged_admin

merged_admin.plot(kind='scatter', x='work_experience', y='bill_rate', figsize=(15, 10), s=100)

merged_admin_df = merged_admin[['bill_rate', 'work_experience']]
merged_admin_df.corr(method='pearson')
# Out:
#                  bill_rate  work_experience
# bill_rate         1.000000         0.103468
# work_experience   0.103468         1.000000

# %%
merged_it = merged[(merged['job_category'] == 'IT & Networking') & (merged['hours_worked'] > 0)]

merged_it

merged_it.plot(kind='scatter', x='bill_rate', y='hours_worked', figsize=(15, 10), s=100)

merged_it_df = merged_it[['bill_rate', 'hours_worked']]
merged_it_df.corr(method='pearson')
# Out:
#               bill_rate  hours_worked
# bill_rate      1.000000     -0.006416
# hours_worked  -0.006416      1.000000

# %%
merged_it = merged[(merged['job_category'] == 'IT & Networking')]

merged_it

merged_it.plot(kind='scatter', x='work_experience', y='bill_rate', figsize=(15, 10), s=100)

merged_it_df = merged_it[['bill_rate', 'work_experience']]
merged_it_df.corr(method='pearson')
# Out:
#                  bill_rate  work_experience
# bill_rate         1.000000         0.071319
# work_experience   0.071319         1.000000

# %%
merged_eng = merged[(merged['job_category'] == 'Engineering & Architecture') & (merged['hours_worked'] > 0)]

merged_eng

merged_eng.plot(kind='scatter', x='bill_rate', y='hours_worked', figsize=(15, 10), s=100)

merged_eng_df = merged_eng[['bill_rate', 'hours_worked']]
merged_eng_df.corr(method='pearson')
# Out:
#               bill_rate  hours_worked
# bill_rate      1.000000      0.057677
# hours_worked   0.057677      1.000000

# %% [markdown]
# ## Cross-correlation Matrix of Covariates
#
# (I realized I can't do this because some of these are categorical variables)

# %%
cross_correlation_df = merged[['job_category', 'work_experience', 'education', 'new_age_range_id', 'final_gender']]

cross_correlation_df.corr()
# Out:
#                  work_experience
# work_experience              1.0

# %% [markdown]
# ## Distribution of Education Levels

# %%
edu_table= merged.groupby('education').count()
print edu_table
# Out:
#                            Unnamed: 0  user_count  worker_id_x  bill_rate  \
# education
# Bachelor or Higher              36632       36632        36632      36632
# High School                      1340        1340         1340       1340
# Less Than High School             761         761          761        761
# Some College or Associate        9302        9302         9302       9302
#
#                            job_category  job_category_id  jobs_completed  \
# education
# Bachelor or Higher                36632            36632           36632
# High School                        1340             1340            1340
# Less Than High School               761              761             761
# Some College or Associate          9302             9302            9302
#
#                            profile_desc_x  hours_worked  feedback_score  \
# education
# Bachelor or Higher                  36632         36632           36632
# High School                          1340          1340            1340
# Less Than High School                 761           761             761
# Some College or Associate            9302          9302            9302
#
#                                ...       gender_detector  sex_machine  \
# education                      ...
# Bachelor or Higher             ...                 36632        36632
# High School                    ...                  1340         1340
# Less Than High School          ...                   761          761
# Some College or Associate      ...                  9302         9302
#
#                            gender_pronoun  work_experience  education_id  \
# education
# Bachelor or Higher                  36632            36632         36632
# High School                          1340             1340          1340
# Less Than High School                 761              761           761
# Some College or Associate            9302             9302          9302
#
#                            ed_list  new_age_range_id  disagree_w_faceapi  \
# education
# Bachelor or Higher           36632             36632               36632
# High School                   1340              1340                1340
# Less Than High School          761               761                 761
# Some College or Associate     9302              9302                9302
#
#                            firstname_gender  final_gender
# education
# Bachelor or Higher                    36632         36632
# High School                            1340          1340
# Less Than High School                   761           761
# Some College or Associate              9302          9302
#
# [4 rows x 30 columns]

# %% [markdown]
# ## Regressions Showing Influence of Job Category on Pay Gap
#
# These are regressions on the log of the hourly bill rates so that we can interpret the coefficients as percentage changes.

# %%
def log_this(row):
    return math.log10(row['bill_rate'])

merged['log_bill_rate'] = merged.apply(log_this, axis=1) # Convert to log of hourly bill rates
# Out:
# 1.39794000867

# %%
model = ols("log_bill_rate ~ final_gender + job_category + work_experience + new_age_range_id + education", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.173
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     457.0
# Date:                Wed, 21 Feb 2018   Prob (F-statistic):               0.00
# Time:                        14:42:11   Log-Likelihood:                -5259.6
# No. Observations:               48035   AIC:                         1.057e+04
# Df Residuals:                   48012   BIC:                         1.077e+04
# Df Model:                          22
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                      1.5196      0.012    129.983      0.000       1.497       1.542
# final_gender[T.male]                           0.0391      0.003     14.897      0.000       0.034       0.044
# job_category[T.Admin Support]                 -0.2820      0.006    -44.279      0.000      -0.295      -0.270
# job_category[T.Customer Service]              -0.3014      0.009    -31.935      0.000      -0.320      -0.283
# job_category[T.Data Science & Analytics]      -0.0642      0.008     -7.710      0.000      -0.081      -0.048
# job_category[T.Design & Creative]             -0.1121      0.006    -19.161      0.000      -0.124      -0.101
# job_category[T.Engineering & Architecture]    -0.0728      0.009     -8.062      0.000      -0.090      -0.055
# job_category[T.IT & Networking]                0.0127      0.009      1.393      0.164      -0.005       0.030
# job_category[T.Legal]                          0.0149      0.015      0.990      0.322      -0.015       0.044
# job_category[T.Sales & Marketing]             -0.0249      0.007     -3.655      0.000      -0.038      -0.012
# job_category[T.Translation]                   -0.2476      0.009    -28.542      0.000      -0.265      -0.231
# job_category[T.Web, Mobile & Software Dev]    -0.0575      0.006     -9.256      0.000      -0.070      -0.045
# job_category[T.Writing]                       -0.1822      0.006    -30.966      0.000      -0.194      -0.171
# new_age_range_id[T.2]                          0.0302      0.011      2.742      0.006       0.009       0.052
# new_age_range_id[T.3]                          0.0583      0.011      5.541      0.000       0.038       0.079
# new_age_range_id[T.4]                          0.0872      0.011      8.193      0.000       0.066       0.108
# new_age_range_id[T.5]                          0.0964      0.011      8.516      0.000       0.074       0.119
# new_age_range_id[T.6]                          0.1006      0.014      7.230      0.000       0.073       0.128
# new_age_range_id[T.7]                          0.0822      0.016      5.256      0.000       0.052       0.113
# education[T.High School]                      -0.1523      0.008    -20.141      0.000      -0.167      -0.137
# education[T.Less Than High School]            -0.1497      0.010    -15.068      0.000      -0.169      -0.130
# education[T.Some College or Associate]        -0.0575      0.003    -18.104      0.000      -0.064      -0.051
# work_experience                                0.0082      0.000     44.826      0.000       0.008       0.009
# ==============================================================================
# Omnibus:                     1274.815   Durbin-Watson:                   1.546
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2575.806
# Skew:                           0.176   Prob(JB):                         0.00
# Kurtosis:                       4.079   Cond. No.                         200.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                        sum_sq       df            F         PR(>F)
# final_gender        16.181928      1.0   221.917132   4.469308e-50
# job_category       362.168782     11.0   451.521977   0.000000e+00
# new_age_range_id    21.179588      6.0    48.409079   1.388315e-59
# education           61.374727      3.0   280.562023  1.496306e-180
# work_experience    146.523674      1.0  2009.409104   0.000000e+00
# Residual          3500.976785  48012.0          NaN            NaN
# Intercept                                     1.519575
# final_gender[T.male]                          0.039116
# job_category[T.Admin Support]                -0.282022
# job_category[T.Customer Service]             -0.301384
# job_category[T.Data Science & Analytics]     -0.064207
# job_category[T.Design & Creative]            -0.112087
# job_category[T.Engineering & Architecture]   -0.072798
# job_category[T.IT & Networking]               0.012668
# job_category[T.Legal]                         0.014902
# job_category[T.Sales & Marketing]            -0.024887
# job_category[T.Translation]                  -0.247644
# job_category[T.Web, Mobile & Software Dev]   -0.057531
# job_category[T.Writing]                      -0.182178
# new_age_range_id[T.2]                         0.030180
# new_age_range_id[T.3]                         0.058252
# new_age_range_id[T.4]                         0.087214
# new_age_range_id[T.5]                         0.096445
# new_age_range_id[T.6]                         0.100582
# new_age_range_id[T.7]                         0.082196
# education[T.High School]                     -0.152290
# education[T.Less Than High School]           -0.149687
# education[T.Some College or Associate]       -0.057542
# work_experience                               0.008247
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + job_category + work_experience", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.153
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     668.9
# Date:                Wed, 21 Feb 2018   Prob (F-statistic):               0.00
# Time:                        14:44:57   Log-Likelihood:                -5828.5
# No. Observations:               48035   AIC:                         1.168e+04
# Df Residuals:                   48021   BIC:                         1.181e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                      1.5750      0.006    280.864      0.000       1.564       1.586
# final_gender[T.male]                           0.0398      0.003     15.018      0.000       0.035       0.045
# job_category[T.Admin Support]                 -0.3011      0.006    -46.952      0.000      -0.314      -0.289
# job_category[T.Customer Service]              -0.3330      0.009    -35.063      0.000      -0.352      -0.314
# job_category[T.Data Science & Analytics]      -0.0601      0.008     -7.135      0.000      -0.077      -0.044
# job_category[T.Design & Creative]             -0.1275      0.006    -21.622      0.000      -0.139      -0.116
# job_category[T.Engineering & Architecture]    -0.0783      0.009     -8.567      0.000      -0.096      -0.060
# job_category[T.IT & Networking]                0.0013      0.009      0.136      0.891      -0.017       0.019
# job_category[T.Legal]                          0.0105      0.015      0.688      0.491      -0.019       0.040
# job_category[T.Sales & Marketing]             -0.0307      0.007     -4.463      0.000      -0.044      -0.017
# job_category[T.Translation]                   -0.2565      0.009    -29.242      0.000      -0.274      -0.239
# job_category[T.Web, Mobile & Software Dev]    -0.0651      0.006    -10.365      0.000      -0.077      -0.053
# job_category[T.Writing]                       -0.1855      0.006    -31.178      0.000      -0.197      -0.174
# work_experience                                0.0086      0.000     46.541      0.000       0.008       0.009
# ==============================================================================
# Omnibus:                     1078.962   Durbin-Watson:                   1.514
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2148.795
# Skew:                           0.138   Prob(JB):                         0.00
# Kurtosis:                       3.999   Cond. No.                         138.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                       sum_sq       df            F        PR(>F)
# final_gender       16.837315      1.0   225.541991  7.299116e-51
# job_category      398.247899     11.0   484.970577  0.000000e+00
# work_experience   161.701168      1.0  2166.046319  0.000000e+00
# Residual         3584.896465  48021.0          NaN           NaN
# Intercept                                     1.574968
# final_gender[T.male]                          0.039774
# job_category[T.Admin Support]                -0.301075
# job_category[T.Customer Service]             -0.332955
# job_category[T.Data Science & Analytics]     -0.060105
# job_category[T.Design & Creative]            -0.127465
# job_category[T.Engineering & Architecture]   -0.078251
# job_category[T.IT & Networking]               0.001254
# job_category[T.Legal]                         0.010476
# job_category[T.Sales & Marketing]            -0.030740
# job_category[T.Translation]                  -0.256548
# job_category[T.Web, Mobile & Software Dev]   -0.065120
# job_category[T.Writing]                      -0.185548
# work_experience                               0.008624
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + job_category", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.115
# Method:                 Least Squares   F-statistic:                     520.6
# Date:                Wed, 21 Feb 2018   Prob (F-statistic):               0.00
# Time:                        14:43:15   Log-Likelihood:                -6888.1
# No. Observations:               48035   AIC:                         1.380e+04
# Df Residuals:                   48022   BIC:                         1.392e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                      1.6371      0.006    294.049      0.000       1.626       1.648
# final_gender[T.male]                           0.0420      0.003     15.504      0.000       0.037       0.047
# job_category[T.Admin Support]                 -0.3130      0.007    -47.782      0.000      -0.326      -0.300
# job_category[T.Customer Service]              -0.3461      0.010    -35.668      0.000      -0.365      -0.327
# job_category[T.Data Science & Analytics]      -0.0828      0.009     -9.633      0.000      -0.100      -0.066
# job_category[T.Design & Creative]             -0.1524      0.006    -25.393      0.000      -0.164      -0.141
# job_category[T.Engineering & Architecture]    -0.0975      0.009    -10.450      0.000      -0.116      -0.079
# job_category[T.IT & Networking]               -0.0152      0.009     -1.623      0.105      -0.034       0.003
# job_category[T.Legal]                          0.0100      0.016      0.643      0.520      -0.021       0.041
# job_category[T.Sales & Marketing]             -0.0447      0.007     -6.352      0.000      -0.058      -0.031
# job_category[T.Translation]                   -0.2848      0.009    -31.828      0.000      -0.302      -0.267
# job_category[T.Web, Mobile & Software Dev]    -0.0898      0.006    -14.036      0.000      -0.102      -0.077
# job_category[T.Writing]                       -0.1938      0.006    -31.864      0.000      -0.206      -0.182
# ==============================================================================
# Omnibus:                      814.197   Durbin-Watson:                   1.471
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1527.127
# Skew:                           0.097   Prob(JB):                         0.00
# Kurtosis:                       3.852   Cond. No.                         19.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                    sum_sq       df           F        PR(>F)
# final_gender    18.753646      1.0  240.374788  4.408276e-54
# job_category   394.990598     11.0  460.253672  0.000000e+00
# Residual      3746.597634  48022.0         NaN           NaN
# Intercept                                     1.637137
# final_gender[T.male]                          0.041970
# job_category[T.Admin Support]                -0.312975
# job_category[T.Customer Service]             -0.346093
# job_category[T.Data Science & Analytics]     -0.082823
# job_category[T.Design & Creative]            -0.152401
# job_category[T.Engineering & Architecture]   -0.097476
# job_category[T.IT & Networking]              -0.015234
# job_category[T.Legal]                         0.010005
# job_category[T.Sales & Marketing]            -0.044676
# job_category[T.Translation]                  -0.284784
# job_category[T.Web, Mobile & Software Dev]   -0.089828
# job_category[T.Writing]                      -0.193772
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + work_experience", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     1513.
# Date:                Wed, 21 Feb 2018   Prob (F-statistic):               0.00
# Time:                        14:46:24   Log-Likelihood:                -8358.5
# No. Observations:               48035   AIC:                         1.672e+04
# Df Residuals:                   48032   BIC:                         1.675e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4127      0.002    651.021      0.000       1.408       1.417
# final_gender[T.male]     0.0888      0.003     33.774      0.000       0.084       0.094
# work_experience          0.0085      0.000     43.711      0.000       0.008       0.009
# ==============================================================================
# Omnibus:                      897.979   Durbin-Watson:                   1.424
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1373.915
# Skew:                           0.200   Prob(JB):                    4.55e-299
# Kurtosis:                       3.725   Cond. No.                         20.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                       sum_sq       df            F         PR(>F)
# final_gender       94.595338      1.0  1140.707660  3.733465e-247
# work_experience   158.443867      1.0  1910.645242   0.000000e+00
# Residual         3983.144364  48032.0          NaN            NaN
# Intercept               1.412684
# final_gender[T.male]    0.088823
# work_experience         0.008456
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + education", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     580.4
# Date:                Wed, 21 Feb 2018   Prob (F-statistic):               0.00
# Time:                        14:47:02   Log-Likelihood:                -8691.9
# No. Observations:               48035   AIC:                         1.739e+04
# Df Residuals:                   48030   BIC:                         1.744e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  1.4802      0.002    726.481      0.000       1.476       1.484
# final_gender[T.male]                       0.0896      0.003     33.843      0.000       0.084       0.095
# education[T.High School]                  -0.1952      0.008    -24.204      0.000      -0.211      -0.179
# education[T.Less Than High School]        -0.1935      0.011    -18.216      0.000      -0.214      -0.173
# education[T.Some College or Associate]    -0.0712      0.003    -21.139      0.000      -0.078      -0.065
# ==============================================================================
# Omnibus:                      887.003   Durbin-Watson:                   1.411
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1328.916
# Skew:                           0.205   Prob(JB):                    2.69e-289
# Kurtosis:                       3.704   Cond. No.                         9.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                    sum_sq       df            F         PR(>F)
# final_gender    96.314670      1.0  1145.382312  3.800788e-248
# education      102.767696      3.0   407.374084  2.398975e-261
# Residual      4038.820535  48030.0          NaN            NaN
# Intercept                                 1.480243
# final_gender[T.male]                      0.089642
# education[T.High School]                 -0.195221
# education[T.Less Than High School]       -0.193485
# education[T.Some College or Associate]   -0.071178
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender + new_age_range_id", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     220.3
# Date:                Wed, 21 Feb 2018   Prob (F-statistic):          9.88e-324
# Time:                        14:48:01   Log-Likelihood:                -9066.4
# No. Observations:               48035   AIC:                         1.815e+04
# Df Residuals:                   48027   BIC:                         1.822e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.3755      0.011    122.001      0.000       1.353       1.398
# final_gender[T.male]      0.0832      0.003     31.076      0.000       0.078       0.088
# new_age_range_id[T.2]     0.0373      0.012      3.134      0.002       0.014       0.061
# new_age_range_id[T.3]     0.0752      0.011      6.609      0.000       0.053       0.097
# new_age_range_id[T.4]     0.1134      0.012      9.848      0.000       0.091       0.136
# new_age_range_id[T.5]     0.1299      0.012     10.605      0.000       0.106       0.154
# new_age_range_id[T.6]     0.1312      0.015      8.721      0.000       0.102       0.161
# new_age_range_id[T.7]     0.1261      0.017      7.458      0.000       0.093       0.159
# ==============================================================================
# Omnibus:                      778.976   Durbin-Watson:                   1.411
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1164.976
# Skew:                           0.182   Prob(JB):                    1.07e-253
# Kurtosis:                       3.670   Cond. No.                         29.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                        sum_sq       df           F         PR(>F)
# final_gender        82.486945      1.0  965.703755  6.221781e-210
# new_age_range_id    39.294439      6.0   76.672310   9.962154e-96
# Residual          4102.293792  48027.0         NaN            NaN
# Intercept                1.375500
# final_gender[T.male]     0.083224
# new_age_range_id[T.2]    0.037328
# new_age_range_id[T.3]    0.075174
# new_age_range_id[T.4]    0.113383
# new_age_range_id[T.5]    0.129861
# new_age_range_id[T.6]    0.131243
# new_age_range_id[T.7]    0.126107
# dtype: float64

# %%
model = ols("log_bill_rate ~ final_gender", merged).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(model.summary())
print anova_table

print model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_bill_rate   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     1072.
# Date:                Wed, 21 Feb 2018   Prob (F-statistic):          1.33e-232
# Time:                        14:43:49   Log-Likelihood:                -9295.4
# No. Observations:               48035   AIC:                         1.859e+04
# Df Residuals:                   48033   BIC:                         1.861e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.4589      0.002    755.042      0.000       1.455       1.463
# final_gender[T.male]     0.0878      0.003     32.745      0.000       0.083       0.093
# ==============================================================================
# Omnibus:                      713.087   Durbin-Watson:                   1.385
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1048.236
# Skew:                           0.173   Prob(JB):                    2.39e-228
# Kurtosis:                       3.635   Cond. No.                         2.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                    sum_sq       df            F         PR(>F)
# final_gender    92.450002      1.0  1072.209666  1.331708e-232
# Residual      4141.588232  48033.0          NaN            NaN
# Intercept               1.458902
# final_gender[T.male]    0.087806
# dtype: float64

# %% [markdown]
# ## Pay Gap for Final Dataset

# %%
merged['bill_rate'] = merged.bill_rate.astype('float')
sd = np.std(merged['bill_rate'])
mean = np.mean(merged['bill_rate'])
median = np.median(merged['bill_rate'])
print("Bill rate average: {0}".format(mean))
print("Bill rate standard deviation: {0}".format(sd))
print("Bill rate median: {0}".format(median))

gender_table= merged.groupby('final_gender')['bill_rate'].mean()
print "Mean bill rates"
print gender_table

gender_table= merged.groupby('final_gender')['bill_rate'].median()
print "Median bill rates"
print gender_table

gender_table= merged.groupby('final_gender')['bill_rate'].std()
print "Standard deviation of bill rates"
print gender_table
# Out:
# Bill rate average: 41.052162798
# Bill rate standard deviation: 39.309463331
# Bill rate median: 30.0
# Mean bill rates
# final_gender
# female    36.077806
# male      45.658529
# Name: bill_rate, dtype: float64
# Median bill rates
# final_gender
# female    27.0
# male      35.0
# Name: bill_rate, dtype: float64
# Standard deviation of bill rates
# final_gender
# female    32.762152
# male      44.024873
# Name: bill_rate, dtype: float64

# %% [markdown]
# ## Pay Gap for Omitted Data

# %%
merged2['bill_rate'] = merged2.bill_rate.astype('float')
sd = np.std(merged2['bill_rate'])
mean = np.mean(merged2['bill_rate'])
median = np.median(merged2['bill_rate'])
print("Bill rate average: {0}".format(mean))
print("Bill rate standard deviation: {0}".format(sd))
print("Bill rate median: {0}".format(median))

gender2_table= merged2.groupby('final_gender')['bill_rate'].mean()
print "Mean bill rates"
print gender2_table

gender2_table= merged2.groupby('final_gender')['bill_rate'].median()
print "Median bill rates"
print gender2_table

gender2_table= merged2.groupby('final_gender')['bill_rate'].std()
print "Standard deviation of bill rates"
print gender2_table
# Out:
# Bill rate average: 44.8874475478
# Bill rate standard deviation: 57.0253741826
# Bill rate median: 30.0
# Mean bill rates
# final_gender
# ambiguous    34.979125
# female       37.126057
# male         51.613470
# unknown      39.700527
# Name: bill_rate, dtype: float64
# Median bill rates
# final_gender
# ambiguous    29.0
# female       25.0
# male         35.0
# unknown      30.0
# Name: bill_rate, dtype: float64
# Standard deviation of bill rates
# final_gender
# ambiguous    25.969849
# female       41.640315
# male         68.542508
# unknown      32.660656
# Name: bill_rate, dtype: float64

# %% [markdown]
# ## Stats for Omitted Data

# %%
merged2_gender = merged2.groupby('final_gender').count()
print merged2_gender
# Out:
#               Unnamed: 0  user_count  worker_id_x  bill_rate  job_category  \
# final_gender
# ambiguous             80          80           80         80            80
# female              2805        2805         2805       2805          2805
# male                3896        3896         3896       3896          3896
# unknown              702         702          702        702           702
#
#               job_category_id  jobs_completed  profile_desc_x  hours_worked  \
# final_gender
# ambiguous                  80              80              80            80
# female                   2805            2805            2805          2805
# male                     3896            3896            3896          3896
# unknown                   702             702             702           702
#
#               feedback_score        ...         gender_detector  sex_machine  \
# final_gender                        ...
# ambiguous                 80        ...                      80           80
# female                  2805        ...                    2805         2805
# male                    3896        ...                    3896         3896
# unknown                  702        ...                     701          702
#
#               gender_pronoun  work_experience  education  education_id  \
# final_gender
# ambiguous                 80               80         80            80
# female                  2805             2805       2805          2805
# male                    3896             3896       3896          3896
# unknown                  702              702        702           702
#
#               ed_list  new_age_range_id  disagree_w_faceapi  firstname_gender
# final_gender
# ambiguous          80                80                  80                80
# female           2805              2805                2805              2805
# male             3896              3896                3896              3896
# unknown           702               702                 702               702
#
# [4 rows x 30 columns]

# %% [markdown]
# ## Bill Rate by Age

# %%
age_table= merged.groupby('new_age_range_id').count()
print age_table
age_table.plot(kind="bar", figsize=(8,8))
# Out:
#                   Unnamed: 0  user_count  worker_id_x  bill_rate  \
# new_age_range_id
# 1                        679         679          679        679
# 2                       5314        5314         5314       5314
# 3                      24216       24216        24216      24216
# 4                      12888       12888        12888      12888
# 5                       3554        3554         3554       3554
# 6                        850         850          850        850
# 7                        534         534          534        534
#
#                   job_category  job_category_id  jobs_completed  \
# new_age_range_id
# 1                          679              679             679
# 2                         5314             5314            5314
# 3                        24216            24216           24216
# 4                        12888            12888           12888
# 5                         3554             3554            3554
# 6                          850              850             850
# 7                          534              534             534
#
#                   profile_desc_x  hours_worked  feedback_score      ...       \
# new_age_range_id                                                    ...
# 1                            679           679             679      ...
# 2                           5314          5314            5314      ...
# 3                          24216         24216           24216      ...
# 4                          12888         12888           12888      ...
# 5                           3554          3554            3554      ...
# 6                            850           850             850      ...
# 7                            534           534             534      ...
#
#                   gender_detector  sex_machine  gender_pronoun  \
# new_age_range_id
# 1                             679          679             679
# 2                            5314         5314            5314
# 3                           24216        24216           24216
# 4                           12888        12888           12888
# 5                            3554         3554            3554
# 6                             850          850             850
# 7                             534          534             534
#
#                   work_experience  education  education_id  ed_list  \
# new_age_range_id
# 1                             679        679           679      679
# 2                            5314       5314          5314     5314
# 3                           24216      24216         24216    24216
# 4                           12888      12888         12888    12888
# 5                            3554       3554          3554     3554
# 6                             850        850           850      850
# 7                             534        534           534      534
#
#                   disagree_w_faceapi  firstname_gender  final_gender
# new_age_range_id
# 1                                679               679           679
# 2                               5314              5314          5314
# 3                              24216             24216         24216
# 4                              12888             12888         12888
# 5                               3554              3554          3554
# 6                                850               850           850
# 7                                534               534           534
#
# [7 rows x 30 columns]

# %%
age_table= merged.groupby('new_age_range_id')['bill_rate'].mean()
age_table.plot(kind="bar", figsize=(8,8))

# %% [markdown]
# ## Bill Rate Across Job Categories

# %%
gender_table= merged.groupby('job_category')['bill_rate'].mean()
gender_table.plot(kind="bar", figsize=(8,8))

# %%
gender_table2= merged2.groupby('job_category')['bill_rate'].mean()
gender_table2.plot(kind="bar", figsize=(8,8))

# %% [markdown]
# ## Percentage Men and Women Across Job Categories

# %%
job_categories = ['Design & Creative', 'Data Science & Analytics', 'Customer Service', 'Admin Support', 
                 'Accounting & Consulting', 'Writing', 'Web, Mobile & Software Dev', 'Translation', 
                 'Sales & Marketing', 'Legal', 'IT & Networking', 'Engineering & Architecture']

representation_of_women = []
representation_gap = []

for category in job_categories:
    
    males_with_job = merged[(merged['final_gender'] == 'male') & (merged['job_category'] == category)]
    male_total = len(males_with_job)
    
    # Calculate the female average bill rate
    females_with_job = merged[(merged['final_gender'] == 'female') & (merged['job_category'] == category)]
    female_total = len(females_with_job)
    
    total_in_category = male_total + female_total
    
    female_percentage = float(female_total)/float(total_in_category) * 100

    representation_of_women.append(female_percentage)
    male_percentage = 100 - female_percentage
    representation_gap.append(male_percentage - female_percentage)
    

representation_df = pd.DataFrame(representation_of_women, index=job_categories, columns=['Percentage Female Workers'])

representation_df = representation_df.sort_values('Percentage Female Workers')
print (representation_df)

representation_df.plot(kind="barh", figsize=(15,10))
# Out:
#                             Percentage Female Workers
# IT & Networking                             20.464768
# Engineering & Architecture                  21.927888
# Web, Mobile & Software Dev                  22.703412
# Data Science & Analytics                    27.381631
# Design & Creative                           44.173249
# Sales & Marketing                           48.104575
# Accounting & Consulting                     48.825941
# Legal                                       58.469945
# Translation                                 59.686888
# Writing                                     61.608301
# Customer Service                            63.893511
# Admin Support                               73.525377

# %%
representation_gap_df = pd.DataFrame(representation_gap, index=job_categories, columns=['Female Representation Gap'])
representation_gap_df = representation_gap_df.sort_values('Female Representation Gap')
print (representation_gap_df)
plt.rcParams.update({'font.size': 22})
graph = representation_gap_df.plot(kind="barh", figsize=(15, 10), legend=None)
graph.set_xlabel("Female Representation Gap (%)")
graph.set_ylabel("Upwork Job Category")
# Out:
#                             Female Representation Gap
# Admin Support                              -47.050754
# Customer Service                           -27.787022
# Writing                                    -23.216602
# Translation                                -19.373777
# Legal                                      -16.939891
# Accounting & Consulting                      2.348118
# Sales & Marketing                            3.790850
# Design & Creative                           11.653501
# Data Science & Analytics                    45.236737
# Web, Mobile & Software Dev                  54.593176
# Engineering & Architecture                  56.144224
# IT & Networking                             59.070465

# %% [markdown]
# ## What are the highest paying job categories on Upwork?

# %%
job_categories = ['Design & Creative', 'Data Science & Analytics', 'Customer Service', 'Admin Support', 
                 'Accounting & Consulting', 'Writing', 'Web, Mobile & Software Dev', 'Translation', 
                 'Sales & Marketing', 'Legal', 'IT & Networking', 'Engineering & Architecture']

average_bill_rate = []

total_length = 0

for category in job_categories:
    workers_with_job = merged[(merged['job_category'] == category)]['bill_rate']
    bill_rate_average = np.mean(workers_with_job)
    total_length += len(workers_with_job)
    average_bill_rate.append(bill_rate_average)

bill_rate_df = pd.DataFrame(average_bill_rate, index=job_categories, columns=['average_bill_rate'])
bill_rate_df = bill_rate_df.sort_values('average_bill_rate')

print bill_rate_df
bill_rate_df.plot(kind="bar", figsize=(14,14))

overall_average = np.mean(average_bill_rate)
print "Overall average by job category: {0}".format(overall_average)

print "Overall average without job category: {0}".format(np.mean(merged['bill_rate']))
print "Total length: {0}".format(total_length)
# Out:
#                             average_bill_rate
# Customer Service                    25.243561
# Admin Support                       25.560288
# Translation                         28.017332
# Writing                             35.582109
# Design & Creative                   40.568266
# Engineering & Architecture          45.493974
# Web, Mobile & Software Dev          47.134754
# Data Science & Analytics            47.870890
# Sales & Marketing                   52.719072
# IT & Networking                     58.197361
# Accounting & Consulting             61.051241
# Legal                               64.965164
# Overall average by job category: 44.3670009158
# Overall average without job category: 41.052162798
# Total length: 48035

# %% [markdown]
# ## What are pay discrepancies across job categories?

# %%
pay_discrepancies = []

job_categories = ['Design & Creative', 'Data Science & Analytics', 'Customer Service', 'Admin Support', 
                 'Accounting & Consulting', 'Writing', 'Web, Mobile & Software Dev', 'Translation', 
                 'Sales & Marketing', 'Legal', 'IT & Networking', 'Engineering & Architecture']

list_of_discrepancies = []

for category in job_categories:
    # Calculate the male average bill rate
    males_with_job = merged[(merged['final_gender'] == 'male') & (merged['job_category'] == category) ]['bill_rate']
    male_bill_rate_average = np.mean(males_with_job)
    print "Male bill rate average: {0}".format(male_bill_rate_average)
    
    # Calculate the female average bill rate
    females_with_job = merged[(merged['final_gender'] == 'female') & (merged['job_category'] == category) ]['bill_rate']
    female_bill_rate_average = np.mean(females_with_job)
    print "Female bill rate average: {0}".format(female_bill_rate_average)
    
    female_percentage = float(female_bill_rate_average)/float(male_bill_rate_average) * 100
    
    discrepancy = 100 - female_percentage
    list_of_discrepancies.append(discrepancy)
    
    print "Pay discrepancy for {0}: {1}%".format(category, discrepancy)

discrepancy_df = pd.DataFrame(list_of_discrepancies, index=job_categories, columns=['pay_discrepancy'])
discrepancy_df = discrepancy_df.sort_values('pay_discrepancy')
discrepancy_df.plot(kind="bar", figsize=(15,10))
# Out:
# Male bill rate average: 41.9762925278
# Female bill rate average: 38.788782399
# Pay discrepancy for Design & Creative: 7.59359613923%
# Male bill rate average: 48.5276512176
# Female bill rate average: 46.1291041667
# Pay discrepancy for Data Science & Analytics: 4.94263989859%
# Male bill rate average: 30.0216589862
# Female bill rate average: 22.5434375
# Pay discrepancy for Customer Service: 24.9094211936%
# Male bill rate average: 27.8020854922
# Female bill rate average: 24.753073694
# Pay discrepancy for Admin Support: 10.9668456312%
# Male bill rate average: 68.4442753095
# Female bill rate average: 53.3026641221
# Pay discrepancy for Accounting & Consulting: 22.1225385453%
# Male bill rate average: 38.6607744283
# Female bill rate average: 33.6636145749
# Pay discrepancy for Writing: 12.9256589587%
# Male bill rate average: 48.4541369553
# Female bill rate average: 42.642748876
# Pay discrepancy for Web, Mobile & Software Dev: 11.9935849536%
# Male bill rate average: 28.6298058252
# Female bill rate average: 27.6036612022
# Pay discrepancy for Translation: 3.58418296415%
# Male bill rate average: 56.9218488665
# Female bill rate average: 48.1850978261
# Pay discrepancy for Sales & Marketing: 15.3486775542%
# Male bill rate average: 82.1565789474
# Female bill rate average: 52.7544392523
# Pay discrepancy for Legal: 35.7879308897%
# Male bill rate average: 60.8426578699
# Female bill rate average: 47.9165567766
# Pay discrepancy for IT & Networking: 21.2451289045%
# Male bill rate average: 46.7863713478
# Female bill rate average: 40.8925167785
# Pay discrepancy for Engineering & Architecture: 12.5973748326%

# %%
# Build a scatterplot using the dataframes above

scatter_df = bill_rate_df.join(representation_df, how='outer')

scatter_df = scatter_df.join(discrepancy_df, how='outer')

print scatter_df

scatter_df.plot(kind='scatter', x='average_bill_rate', y='female_percentage', figsize=(15, 10), s=100)
# Out:
#                             average_bill_rate  female_percentage  \
# Accounting & Consulting             61.051241          48.825941
# Admin Support                       25.560288          73.525377
# Customer Service                    25.243561          63.893511
# Data Science & Analytics            47.870890          27.381631
# Design & Creative                   40.568266          44.173249
# Engineering & Architecture          45.493974          21.927888
# IT & Networking                     58.197361          20.464768
# Legal                               64.965164          58.469945
# Sales & Marketing                   52.719072          48.104575
# Translation                         28.017332          59.686888
# Web, Mobile & Software Dev          47.134754          22.703412
# Writing                             35.582109          61.608301
#
#                             pay_discrepancy
# Accounting & Consulting           22.122539
# Admin Support                     10.966846
# Customer Service                  24.909421
# Data Science & Analytics           4.942640
# Design & Creative                  7.593596
# Engineering & Architecture        12.597375
# IT & Networking                   21.245129
# Legal                             35.787931
# Sales & Marketing                 15.348678
# Translation                        3.584183
# Web, Mobile & Software Dev        11.993585
# Writing                           12.925659

# %%
scatter_df.plot(kind='scatter', x='pay_discrepancy', y='female_percentage', figsize=(15, 10), s=100)

# %%
scatter_df.plot(kind='scatter', x='pay_discrepancy', y='average_bill_rate', figsize=(15, 10), s=100)

# %% [markdown]
# ## Highest Level of Education by Gender

# %%
education_table = pd.crosstab(merged['education'], merged['final_gender'])
education_table.plot(kind="bar", figsize=(8,8))

# %% [markdown]
# ## Primary Job Category by Gender

# %%
job_category_table = pd.crosstab(merged['job_category'], merged['gender'])
job_category_table.plot(kind="bar", figsize=(8,8))

# %% [markdown]
# ## Work Experience by Gender and Age

# %%
# Get work experience distribution 
merged.hist(column='work_experience', figsize=(8,8), color="purple", bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f03f2f1a190>]], dtype=object)

# %%
# Work experience distribution for women 
female_df = merged[merged['final_gender'] == 'female']

female_df.hist(column='work_experience', figsize=(8,8), color="red", bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f03f2d60090>]], dtype=object)

# %%
# Work experience distribution for men 
male_df = merged[merged['final_gender'] == 'male']
male_df.hist(column='work_experience', figsize=(8,8), color="blue", bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f03f2b33310>]], dtype=object)

# %%
sd = np.std(merged['work_experience'])
mean = np.mean(merged['work_experience'])
median = np.median(merged['work_experience'])
print("Work experience average: {0}".format(mean))
print("Work experience standard deviation: {0}".format(sd))
print("Work experience median: {0}".format(median))

work_experience_table= merged.groupby('final_gender')['work_experience'].mean()
print "Average work experience"
print work_experience_table

work_experience_table= merged.groupby('final_gender')['work_experience'].median()
print "Median work experience"
print work_experience_table

work_experience_table= merged.groupby('final_gender')['work_experience'].std()
print "Standard deviation of work experience"
print work_experience_table
# Out:
# Work experience average: 5.40297699594
# Work experience standard deviation: 6.79180890072
# Work experience median: 3.0
# Average work experience
# final_gender
# female    5.465382
# male      5.345188
# Name: work_experience, dtype: float64
# Median work experience
# final_gender
# female    3.0
# male      3.0
# Name: work_experience, dtype: float64
# Standard deviation of work experience
# final_gender
# female    6.597360
# male      6.966801
# Name: work_experience, dtype: float64

# %% [markdown]
# ## Hours Worked On Upwork by Gender

# %%
merged['hours_worked'] = merged['hours_worked'].astype('float')

sd = np.std(merged['hours_worked'])
mean = np.mean(merged['hours_worked'])
median = np.median(merged['hours_worked'])
print("Hours worked average: {0}".format(mean))
print("Hours worked standard deviation: {0}".format(sd))
print("Hours worked median: {0}".format(median))

hours_table= merged.groupby('final_gender')['hours_worked'].mean()
print "Average Hours worked"
print hours_table

hours_table= merged.groupby('final_gender')['hours_worked'].median()
print "Median Hours worked"
print hours_table

hours_table= merged.groupby('final_gender')['hours_worked'].std()
print "Standard deviation of Hours worked"
print hours_table
# Out:
# Hours worked average: 77.3008480885
# Hours worked standard deviation: 552.866589852
# Hours worked median: 0.0
# Average Hours worked
# final_gender
# female    92.261392
# male      63.447048
# Name: hours_worked, dtype: float64
# Median Hours worked
# final_gender
# female    0.0
# male      0.0
# Name: hours_worked, dtype: float64
# Standard deviation of Hours worked
# final_gender
# female    626.666037
# male      474.001939
# Name: hours_worked, dtype: float64

# %%
# Get hours worked distribution 
merged.hist(column='hours_worked', figsize=(8,8), color="purple", bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f03f29ec9d0>]], dtype=object)

# %% [markdown]
# ### Of those people who have worked at least a portion of an hour

# %%
merged_active = merged[merged['hours_worked'] > 0]
merged_active.hist(column='hours_worked', figsize=(8,8), color="purple", bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f03f2940750>]], dtype=object)

# %%
print "Total number of active users: {0}".format(len(merged_active))
print "Number of female active users: {0}".format(len(merged_active[merged_active['final_gender'] == 'female']))
print "Number of male active users: {0}".format(len(merged_active[merged_active['final_gender'] == 'male']))

sd = np.std(merged_active['hours_worked'])
mean = np.mean(merged_active['hours_worked'])
median = np.median(merged_active['hours_worked'])
print("Hours worked average: {0}".format(mean))
print("Hours worked standard deviation: {0}".format(sd))
print("Hours worked median: {0}".format(median))

hours_table= merged_active.groupby('final_gender')['hours_worked'].mean()
print "Average Hours worked"
print hours_table

hours_table= merged_active.groupby('final_gender')['hours_worked'].median()
print "Median Hours worked"
print hours_table

hours_table= merged_active.groupby('final_gender')['hours_worked'].std()
print "Standard deviation of Hours worked"
print hours_table
# Out:
# Total number of active users: 9444
# Number of female active users: 4843
# Number of male active users: 4601
# Hours worked average: 393.175162848
# Hours worked standard deviation: 1196.03153118
# Hours worked median: 40.16666666
# Average Hours worked
# final_gender
# female    439.970442
# male      343.918580
# Name: hours_worked, dtype: float64
# Median Hours worked
# final_gender
# female    48.5
# male      33.5
# Name: hours_worked, dtype: float64
# Standard deviation of Hours worked
# final_gender
# female    1311.497294
# male      1059.063474
# Name: hours_worked, dtype: float64

# %% [markdown]
# ## Number of Jobs Completed by Gender

# %%
merged['jobs_completed'] = merged['jobs_completed'].astype('float')
merged_have_worked = merged[merged['jobs_completed'] > 0]

print "Total number of active users: {0}".format(len(merged_have_worked))
print "Number of female active users: {0}".format(len(merged_have_worked[merged_have_worked['final_gender'] == 'female']))
print "Number of male active users: {0}".format(len(merged_have_worked[merged_have_worked['final_gender'] == 'male']))

sd = np.std(merged_have_worked['jobs_completed'])
mean = np.mean(merged_have_worked['jobs_completed'])
median = np.median(merged_have_worked['jobs_completed'])
print("Jobs completed average: {0}".format(mean))
print("Jobs completed standard deviation: {0}".format(sd))
print("Jobs completed median: {0}".format(median))

table = merged_have_worked.groupby('final_gender')['jobs_completed'].mean()
print "Average jobs completed"
print table

table= merged_have_worked.groupby('final_gender')['jobs_completed'].median()
print "Median jobs completed"
print table

table= merged_have_worked.groupby('final_gender')['jobs_completed'].std()
print "Standard deviation of jobs completed"
print table
# Out:
# Total number of active users: 13565
# Number of female active users: 6811
# Number of male active users: 6754
# Jobs completed average: 17.1998525617
# Jobs completed standard deviation: 50.284716237
# Jobs completed median: 4.0
# Average jobs completed
# final_gender
# female    19.277492
# male      15.104679
# Name: jobs_completed, dtype: float64
# Median jobs completed
# final_gender
# female    4.0
# male      3.0
# Name: jobs_completed, dtype: float64
# Standard deviation of jobs completed
# final_gender
# female    57.361877
# male      41.860421
# Name: jobs_completed, dtype: float64

# %%
merged_have_worked['no_reviews'] = merged_have_worked['no_reviews'].astype('float')

sd = np.std(merged_have_worked['no_reviews'])
mean = np.mean(merged_have_worked['no_reviews'])
median = np.median(merged_have_worked['no_reviews'])
print("Reviews average: {0}".format(mean))
print("Reviews standard deviation: {0}".format(sd))
print("Reviews median: {0}".format(median))

table = merged_have_worked.groupby('final_gender')['no_reviews'].mean()
print "Average reviews"
print table

table= merged_have_worked.groupby('final_gender')['no_reviews'].median()
print "Median reviews"
print table

table= merged_have_worked.groupby('final_gender')['no_reviews'].std()
print "Standard deviation of reviews"
print table
# Out:
# Reviews average: 11.091190564
# Reviews standard deviation: 31.4279923371
# Reviews median: 2.0
# Average reviews
# final_gender
# female    12.102628
# male      10.071217
# Name: no_reviews, dtype: float64
# Median reviews
# final_gender
# female    2.0
# male      2.0
# Name: no_reviews, dtype: float64
# Standard deviation of reviews
# final_gender
# female    34.644584
# male      27.777987
# Name: no_reviews, dtype: float64
# /home/ecf384/.conda/envs/eureka2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
