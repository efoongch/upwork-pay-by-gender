# %% [markdown]
# ## Extract available JSON data
# Trying to understand what kinds of data I have access to from the API for CSCW 2018 revisions. Specifically, looking to know if I can get at people's tenure on the website as well as the average job length. 5/30/2018
#
# ### Conclusion
# I don't have access to the date when users joined Upwork; however, I do have access to their earliest "from" date for their earliest job assignment. I also have access to the rate at which workers were paid for each of their assignments, the duration of the assignments, and number of hours worked for each assingment. With this in mind, here's what I plan to do:
#
# (DONE)
# 1. Extract earliest "from" date for a fixed and/or an hourly assignment --> "Upwork_tenure" (add as a control variable in causal model and in regular linear regression - this time using revenue as the outcome variable)
# ** Just realized I don't actually have the from date, I just have the latest "to" date (for some)
# + Add capability to take into account from dates
#
# 2. Create a measure of job duration for hourly assignments. Measure duration of an assignment --> "assignment_duration" by taking the "to" and "from" dates into account. Take an average of the number of hours worked per day by dividing hours worked for each assignment and "assignment_duration" --> "average_daily_hours_worked". Average this out for all the hourly assignments a worker has to compute "average_daily_hours_worked". May also just want to compute the total number of days worked on hourly jobs, calculate the average --> "average_days_of_hourly_jobs". Compare descriptive statistics across job categories, possibly see if there are any patterns between these measures and the job category's average pay, female representation, etc, or if there are any gender differences between these as well. Also, may want to add this as a control variable in a causal analysis/linear regression, where the outcome variable is estimated hourly revenue.
# ** This isn't possible, given that there isn't a "from" date for some random assignments
# ** A fix might be to use the job assignments I collected back in February, and see what was the average workload? Or simply address this in the limitations section of the paper
#
# (IN PROGRESS)
#
# 3. BONUS: I want to compare the actual average rate for all a user's hourly assignments to the listed hourly bill rate. Calculate average rate for hourly assignments --> "actual_hourly_rate", then see if there is still a gender pay gap in terms of hourly rate. Remember to include "Upwork_tenure" as a control variable.
#
# ### June 1, 2018
# Realized I can't get the from date for assignments, so I'm using earliest skill test date as a proxy for Upwork tenure. I also still want to use to date for assignments as a proxy. This might take me another hour to do this.

# %%
import httplib2
import oauth2
import urllib3
import types
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gender_detector import GenderDetector 
import psycopg2, psycopg2.extras
from causalinference import CausalModel
from causalinference.utils import random_data
import httplib
import base64
import json # For Microsoft Face API
import urllib as urllib # For Microsoft Face API
import time 
import csv
import datetime 


class UpworkDataExtractor:
    
    def __init__(self):
        # Connect to the database 
        self.conn = psycopg2.connect("dbname=eureka01")
        self.cur = self.conn.cursor(cursor_factory=psycopg2.extras.DictCursor)
        psycopg2.extensions.register_adapter(dict, psycopg2.extras.Json)
        
        # Get detailed_info from workers in our database
        self.cur.execute("SELECT detailed_info FROM upwork_unitedstates_allskills_2017_12_12 LIMIT 10;")
        
    def print_detailed_info(self):
        
        for user in self.cur:
            print json.dumps(user, indent=2, sort_keys=False)

myObject = UpworkDataExtractor()
myObject.print_detailed_info()
# Out:
# [
#   {
#     "dev_adj_score_recent": "5",
#     "dev_ui_profile_access": "Public",
#     "dev_portrait": "https://odesk-prod-portraits.s3.amazonaws.com/Users:marianaelara:PortraitUrl?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=of%2BHLUkWfSMAba0BC2EHVizCV7U%3D&1502292249360166",
#     "dev_country": "United States",
#     "dev_first_name": "Mariana",
#     "dev_groups": "",
#     "dev_city": "Hartford",
#     "dev_blurb": "I am a Spanish speaker from Argentina. I studied at Universidad Nacional de Cuyo in Mendoza. In my home country I earned a degree as a Teacher of English as a Second Language. I moved to the United States in 2002 and studied at Saint Michael's College where I earned my MA in Teaching English to Speakers of Other Languages. \nWhile in the United States I became a Spanish teacher and taught middle and high school students. Besides teaching, I translated school documents for parents with limited English proficiency. As an animal lover I also volunteer to translate some articles and flyers for the Vegan Outreach website. \nI am currently taking classes to earn my certificate in translation from the University of San Diego. My fields of expertise in translation are education, health, and fitness. \nWhen I am not working, I am training for long distance triathlons or marathons. ",
#     "education": {
#       "institution": [
#         {
#           "ed_to": "01/2018",
#           "ed_area": "English-Spanish translation",
#           "ed_school": "University of San Diego",
#           "ed_comment": "Still attending.",
#           "ed_from": "01/2016",
#           "ed_degree": ""
#         },
#         {
#           "ed_to": "01/2008",
#           "ed_area": "TESOL",
#           "ed_school": "Saint Michael's College",
#           "ed_comment": "",
#           "ed_from": "01/2005",
#           "ed_degree": "Master of Arts (M.A.)"
#         },
#         {
#           "ed_to": "01/2000",
#           "ed_area": "English as a Second Language",
#           "ed_school": "Universidad Nacional de Cuyo",
#           "ed_comment": "",
#           "ed_from": "01/1995",
#           "ed_degree": "Bachelor of Education (B.Ed.)"
#         }
#       ]
#     },
#     "dev_portrait_50": "https://odesk-prod-portraits.s3.amazonaws.com/Users:marianaelara:PortraitUrl_50?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=z5VlTbcofHsDbQ0kwJVz4ZaYCJ8%3D&1502292249360166",
#     "dev_profile_title": "Spanish Teacher, English- Spanish Translator, Editor and Consultant",
#     "dev_portfolio_items_v2_count": "0",
#     "dev_adj_score": "5",
#     "dev_billed_assignments": "3",
#     "dev_portrait_100": "https://odesk-prod-portraits.s3.amazonaws.com/Users:marianaelara:PortraitUrl_100?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=h6ql01Lo9N7rHqAkiiUHUTwpuVM%3D&1502292249360166",
#     "dev_portrait_32": "https://odesk-prod-portraits.s3.amazonaws.com/Users:marianaelara:PortraitUrl_32?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=sOn5RAAPyTudgKTzwAWQT1nGkzg%3D&1502292249360166",
#     "portfolio_items": "",
#     "dev_bill_rate": "25.00",
#     "ciphertext": "~01293c7646ce6e3690",
#     "tsexams": {
#       "tsexam": [
#         {
#           "ts_percentile": "100",
#           "ts_when": "12/02/2017",
#           "ts_pass": "1",
#           "ts_name_raw": "English To Spanish Translation",
#           "ts_score": "5.0000000000000000",
#           "ts_id": "17166492",
#           "ts_duration": "20"
#         },
#         {
#           "ts_percentile": "97",
#           "ts_when": "11/08/2017",
#           "ts_pass": "1",
#           "ts_name_raw": "English Spelling Test (U.S. Version)",
#           "ts_score": "5.0000000000000000",
#           "ts_id": "17078611",
#           "ts_duration": "23"
#         }
#       ]
#     },
#     "dev_last_worked": "December 11, 2017",
#     "dev_timezone": "UTC-05:00 Eastern Time (US & Canada)",
#     "dev_portfolio_items_count": "0",
#     "dev_recno": "16990183",
#     "permalink": "",
#     "dev_eng_skill": "",
#     "dev_last_activity": "December 11, 2017",
#     "skills": {
#       "skill": [
#         {
#           "skl_name": "consulting",
#           "skl_external_link": "https://en.wikipedia.org/wiki/Consultant",
#           "skl_rank": "6",
#           "skl_has_tests": "0",
#           "skl_description": "A consultant is a professional who provides professional or expert advice in a particular area such as management, accountancy, law, or any of many other specialized fields."
#         },
#         {
#           "skl_name": "editing",
#           "skl_description": "Editing is the process of selecting and preparing written, visual, audible, and film media used to convey information through the processes of correction, condensation, organization, and other modifications performed with an intention of producing a correct, consistent, accurate, and complete",
#           "skl_rank": "2",
#           "skl_has_tests": "0",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Editing"
#         },
#         {
#           "skl_name": "esl-teaching",
#           "skl_description": "English as a second language (ESL) is the use or study of English by speakers with different native languages.",
#           "skl_rank": "5",
#           "skl_has_tests": "0",
#           "skl_external_link": ""
#         },
#         {
#           "skl_name": "proofreading",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Proofreading",
#           "skl_rank": "4",
#           "skl_has_tests": "1",
#           "skl_description": "Proofreading (also proof-reading) is the reading of a galley proof or computer monitor to detect and correct production-errors of text or art. Proofreaders are expected to be consistently accurate by default because they occupy the last stage of typographic production before publication."
#         },
#         {
#           "skl_name": "spanish",
#           "skl_description": "Spanish (espaol) is a Romance language named for its origins as the native tongue of a large proportion of the inhabitants of Spain. Spanish is the second most natively spoken language in the world, after Mandarin Chinese.",
#           "skl_rank": "3",
#           "skl_has_tests": "1",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Spanish_language"
#         },
#         {
#           "skl_name": "translation-english-spanish",
#           "skl_external_link": "oDesk Original",
#           "skl_rank": "1",
#           "skl_has_tests": "1",
#           "skl_description": "Translation from English to Spanish and Spanish to English."
#         }
#       ]
#     },
#     "dev_is_affiliated": "0",
#     "dev_tot_feedback": "1",
#     "dev_recno_ciphertext": "~01293c7646ce6e3690",
#     "assignments": {
#       "hr": {
#         "job": [
#           {
#             "as_total_hours": "7.83",
#             "as_rate": "$25.00",
#             "as_to": "Present",
#             "as_total_hours_precise": "7.83333334",
#             "as_opening_title": "Need someone to proofread 2,200 Spanish sentences",
#             "as_job_type": "Hourly",
#             "as_to_full": "Present"
#           },
#           {
#             "as_to": "Present",
#             "as_rate": "$22.22",
#             "as_total_hours": "242",
#             "as_total_hours_precise": "241.66666667",
#             "as_opening_title": "Language Teaching Expert, Spanish -- Create Course Curriculum & Content",
#             "as_job_type": "Hourly",
#             "as_to_full": "Present"
#           }
#         ]
#       },
#       "fp": {
#         "job": [
#           {
#             "as_to": "Present",
#             "as_rate": "$0.00",
#             "as_total_charge": "0",
#             "as_total_hours": "0.00",
#             "as_total_hours_precise": "0",
#             "as_opening_title": "Spanish translation of video descriptions (#4: generic2, road)",
#             "as_job_type": "Fixed",
#             "as_to_full": "Present"
#           },
#           {
#             "as_total_hours": "0.00",
#             "feedback": {
#               "comment": "Easy to work with, A+",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_to": "11/2017",
#             "as_total_hours_precise": "0",
#             "as_opening_title": "English to Spanish Translation: sales copy- 250 words, Quick   Native speakers Only !",
#             "as_job_type": "Fixed",
#             "as_to_full": "11/29/2017"
#           }
#         ]
#       }
#     },
#     "dev_job_categories_v2": {
#       "dev_job_categories_v": {
#         "name": "General Translation",
#         "groups": {
#           "group": {
#             "name": "Translation",
#             "uid": "531770282584862720"
#           }
#         }
#       }
#     },
#     "dev_ac_agencies": "",
#     "dev_short_name": "Mariana Lara A.",
#     "dev_last_worked_ts": "1512950400000",
#     "experiences": {
#       "experience": [
#         {
#           "exp_from": "07/2017",
#           "exp_title_raw": "Language Teaching Expert, Spanish",
#           "exp_comment": "Create course curriculum and content.",
#           "exp_to": "Present",
#           "exp_company": "Duolingo"
#         },
#         {
#           "exp_from": "01/2013",
#           "exp_comment": "",
#           "exp_title_raw": "Spanish Teacher",
#           "exp_to": "06/2017",
#           "exp_company": "Springfield High School"
#         }
#       ]
#     },
#     "dev_total_hours": "250.16666668",
#     "dev_last_name": "Lara A."
#   }
# ]
# [
#   {
#     "dev_adj_score_recent": "4.9348489265",
#     "dev_ui_profile_access": "Public",
#     "dev_portrait": "https://odesk-prod-portraits.s3.amazonaws.com/Users:mab2016:PortraitUrl?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=RNV8NLhwo6DuhxOWah1coj4TLcA%3D&1450996193002367",
#     "dev_country": "United States",
#     "dev_first_name": "Marc",
#     "dev_groups": "",
#     "dev_city": "Chicago",
#     "dev_blurb": "Seasoned Public Relations Expert, Strategist & Writer\n\nMarc has an extensive track record -- +20 years -- of noteworthy success in all dimensions of global PR, corporate communications, marketing and media relations, working for organizations both very large (i.e., General Motors, MCI and Ameritech) and very small (i.e., startups).\n\nHe's obtained press coverage during his career in such top-tier media as The Wall Street Journal, The New York Times, CNBC-TV, CNN, Financial Times, USA Today, Washington Post, Business Week/Bloomberg, Dow Jones, Barrons, National Public Radio, Forbes, Investor's Business Daily, and in leading trade publications.\n\nHe is also an exceptional, very polished writer, a former speechwriter for the National Cable TV Association,  a certified member of the International Association of Professional Writers and Editors, who has had op-eds and articles published under his own name and ghostwritten in such prominent media as The New York Times,  The Washington Post and USA Today.   \n\nHaving spent much of his career in the technology industry -- where \"Geek Gab\" runs rampant -- he's very skilled at distilling arcane language into compelling, succinct headlines and messaging.  He's trained executives and PR staff alike on the fine points of good, effective PR writing.  He's produced successful press releases; white papers; vision papers;  social media video scripts; speeches; marketing books; web site content, including tag lines and identity statements; ads; blogs; and other PR and branding material. \n\nTo see examples of his history of work and successes, please see his portfolio on this site.\n",
#     "education": {
#       "institution": {
#         "ed_to": "01/1989",
#         "ed_area": "",
#         "ed_school": "University of Texas",
#         "ed_comment": "",
#         "ed_from": "01/1989",
#         "ed_degree": "Master of Public Administration (M.P.A.)"
#       }
#     },
#     "dev_last_worked": "December 10, 2017",
#     "dev_profile_title": "Seasoned, Successful Public Relations Expert",
#     "dev_portfolio_items_v2_count": "3",
#     "dev_adj_score": "4.9547170863",
#     "dev_billed_assignments": "27",
#     "dev_portrait_100": "https://odesk-prod-portraits.s3.amazonaws.com/Users:mab2016:PortraitUrl_100?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=H2i79Ge%2F4wxjpFJZT1YKvrE2eNM%3D&1450996193002367",
#     "dev_recno": "10090871",
#     "dev_portrait_32": "https://odesk-prod-portraits.s3.amazonaws.com/Users:mab2016:PortraitUrl_32?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=lf%2Fv88ib85gWazKr8KmAxd1zsxg%3D&1450996193002367",
#     "portfolio_items": "",
#     "dev_bill_rate": "100.00",
#     "ciphertext": "~01532f4aeb4fca879d",
#     "dev_portrait_50": "https://odesk-prod-portraits.s3.amazonaws.com/Users:mab2016:PortraitUrl_50?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=vOhqCwzkX5TLpFvWq4vJMXHIxTo%3D&1450996193002367",
#     "dev_timezone": "UTC-06:00 Central Time (US & Canada)",
#     "dev_portfolio_items_count": "0",
#     "portfolio_items_v2": {
#       "portfolio_items_v": [
#         {
#           "pi_large_thumbnail": "",
#           "pi_recno": "855595957929402368",
#           "pi_title": "Pitch IT Survey to Press",
#           "pi_image": ""
#         },
#         {
#           "pi_large_thumbnail": "",
#           "pi_image": "",
#           "pi_title": "Examples of Published Writing and PR Successes",
#           "pi_recno": "855594321915961344"
#         },
#         {
#           "pi_large_thumbnail": "",
#           "pi_image": "",
#           "pi_title": "Strimm TV",
#           "pi_recno": "855593313454100480"
#         }
#       ]
#     },
#     "tsexams": "",
#     "permalink": "",
#     "dev_eng_skill": "5",
#     "dev_last_activity": "December 8, 2017",
#     "skills": {
#       "skill": [
#         {
#           "skl_name": "communications",
#           "skl_external_link": "",
#           "skl_rank": "2",
#           "skl_has_tests": "0",
#           "skl_description": ""
#         },
#         {
#           "skl_name": "corporate-brand-identity",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Corporate_branding",
#           "skl_rank": "6",
#           "skl_has_tests": "0",
#           "skl_description": "Corporate branding is the practice of using a company's name as a product brand name. It is an attempt to use corporate brand equity to create brand recognition."
#         },
#         {
#           "skl_name": "marketing-communications",
#           "skl_external_link": "https://en.wikipedia.org/wiki/Marketing_communications",
#           "skl_rank": "9",
#           "skl_has_tests": "0",
#           "skl_description": "Marketing communications (MC) uses different marketing channels and tools in combination: Marketing communication channels focuses on any way a business communicates a message to its desired market, or the market in general. A marketing communication tool can be anything from: advertising, personal selling, direct marketing, sponsorship, communication, promotion and public relations."
#         },
#         {
#           "skl_name": "marketing-strategy",
#           "skl_description": "Marketing strategy is a process that can allow an organization to concentrate its limited resources on the greatest opportunities to increase sales and achieve a sustainable competitive advantage.",
#           "skl_rank": "1",
#           "skl_has_tests": "1",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Marketing_strategy"
#         },
#         {
#           "skl_name": "media-relations",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Media_relations",
#           "skl_rank": "4",
#           "skl_has_tests": "0",
#           "skl_description": "Media relations involves working with various media for the purpose of informing the public of an organization's mission, policies and practices in a positive, consistent and credible manner."
#         },
#         {
#           "skl_name": "press-release-writing",
#           "skl_description": "A press release is a written or recorded communication directed at members of the news media for the purpose of announcing something ostensibly newsworthy. Typically, they are mailed, faxed, or e-mailed to assignment editors at newspapers, magazines, radio stations, and television networks.",
#           "skl_rank": "7",
#           "skl_has_tests": "0",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Press_release"
#         },
#         {
#           "skl_name": "public-relations",
#           "skl_description": "Public relations (PR) is the practice of managing the flow of information between an organization and its publics. Public relations provides an organization or individual exposure to their audiences using topics of public interest and news items that do not require direct payment.",
#           "skl_rank": "3",
#           "skl_has_tests": "0",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Public_relations"
#         },
#         {
#           "skl_name": "report-writing",
#           "skl_description": "A report is a textual work (usually of writing, speech, television, or film) made with the specific intention of relaying information or recounting certain events in a widely presentable form.",
#           "skl_rank": "8",
#           "skl_has_tests": "1",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Report"
#         },
#         {
#           "skl_name": "social-media-management",
#           "skl_description": "",
#           "skl_rank": "5",
#           "skl_has_tests": "0",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Social_media"
#         },
#         {
#           "skl_name": "speech-writing",
#           "skl_external_link": "http://en.wikipedia.org/wiki/Speechwriter",
#           "skl_rank": "10",
#           "skl_has_tests": "0",
#           "skl_description": "A speechwriter is a person who is hired to prepare and write speeches that will be delivered by another person. Speechwriters are used by many senior-level elected officials and executives in the government and private sectors."
#         }
#       ]
#     },
#     "dev_is_affiliated": "0",
#     "dev_tot_feedback": "18",
#     "dev_recno_ciphertext": "~01532f4aeb4fca879d",
#     "assignments": {
#       "hr": {
#         "job": [
#           {
#             "as_total_hours": "0.00",
#             "as_rate": "$100.00",
#             "as_financial_privacy": "0",
#             "as_to": "Present",
#             "as_from_full": "12/08/2017",
#             "as_ciphertext_opening_recno": "~010ffd80cb3583e54e",
#             "as_total_hours_precise": "0",
#             "as_opening_title": "Help with PR and media outreach plan and launch of the GovCon Incubator",
#             "as_job_type": "Hourly",
#             "as_to_full": "Present",
#             "as_agency_name": "",
#             "as_total_charge": "0"
#           },
#           {
#             "as_total_hours": "3.33",
#             "as_rate": "$55.00",
#             "as_total_charge": "183.33",
#             "as_to": "Present",
#             "as_from_full": "10/31/2017",
#             "as_ciphertext_opening_recno": "~01d3f8606c3ffbb394",
#             "as_total_hours_precise": "3.33333333",
#             "as_opening_title": "(2) Professional Biographical Sketches",
#             "as_job_type": "Hourly",
#             "as_agency_name": "",
#             "as_to_full": "Present",
#             "as_financial_privacy": "0"
#           },
#           {
#             "as_to": "10/2017",
#             "as_rate": "$85.00",
#             "as_financial_privacy": "0",
#             "as_total_hours": "1.67",
#             "as_from_full": "10/30/2017",
#             "as_ciphertext_opening_recno": "~01403067b4f165e48e",
#             "feedback": {
#               "comment": "Marc was able to turn my project around very quickly.",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_total_hours_precise": "1.66666667",
#             "as_opening_title": "Press Release - Technology company announcing the hire of a new VP of Sales & Marketing",
#             "as_job_type": "Hourly",
#             "as_to_full": "10/31/2017",
#             "as_agency_name": "",
#             "as_total_charge": "141.67"
#           },
#           {
#             "as_total_hours": "5.00",
#             "as_rate": "$55.00",
#             "as_financial_privacy": "0",
#             "as_to": "10/2017",
#             "as_from_full": "10/24/2017",
#             "as_ciphertext_opening_recno": "~0147f5b56b45229f94",
#             "feedback": {
#               "comment": "Great feedback. Wealth of PR expertise. Project completed early. Thanks Marc!",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_total_hours_precise": "5",
#             "as_opening_title": "Public relations + business expert to review paper about innovation within the public relations function",
#             "as_job_type": "Hourly",
#             "as_to_full": "10/25/2017",
#             "as_agency_name": "",
#             "as_total_charge": "275"
#           },
#           {
#             "as_total_hours": "2.00",
#             "as_rate": "$50.00",
#             "as_total_charge": "100",
#             "as_to": "11/2017",
#             "as_total_hours_precise": "2",
#             "as_opening_title": "Need Skilled Public Relations Professional for New Software Press Release",
#             "as_job_type": "Hourly",
#             "as_to_full": "11/22/2017",
#             "feedback": {
#               "comment": "Marc was great to work with. He followed all guidelines and met all our deadlines while giving us constant updates on the status of the Press Release. We appreciated his expertise and input in terms of Press Release best practices, which ultimately led to a better result. This is the second time we work with Marc and would be happy to continue working with him in the future.",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             }
#           },
#           {
#             "as_to": "Present",
#             "as_rate": "$50.00",
#             "as_total_charge": "2500",
#             "as_total_hours": "4.50",
#             "as_from_full": "09/25/2017",
#             "as_ciphertext_opening_recno": "~016ac925019f320e83",
#             "as_total_hours_precise": "4.5",
#             "as_opening_title": "Media Relations/PR Pitcher Needed for Marketing Software Company",
#             "as_job_type": "Hourly",
#             "as_agency_name": "",
#             "as_to_full": "Present",
#             "as_financial_privacy": "0"
#           },
#           {
#             "as_total_hours": "2.00",
#             "as_rate": "$50.00",
#             "feedback": {
#               "comment": "Marc was great to work with. Easy to communicate with and always delivered on time. Press Release was just what we were looking for so definitely would hire again for any future PR projects.",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_to": "10/2017",
#             "as_total_hours_precise": "2",
#             "as_opening_title": "Need Skilled Public Relations Professional for New Software Press Release",
#             "as_job_type": "Hourly",
#             "as_to_full": "10/18/2017",
#             "as_total_charge": "100"
#           },
#           {
#             "as_total_hours": "0.00",
#             "as_rate": "$55.00",
#             "as_financial_privacy": "0",
#             "as_to": "Present",
#             "as_from_full": "08/22/2017",
#             "as_ciphertext_opening_recno": "~01b3382715ce81244b",
#             "as_total_hours_precise": "0",
#             "as_opening_title": "Building A Story and Relate it to the public.",
#             "as_job_type": "Hourly",
#             "as_to_full": "Present",
#             "as_agency_name": "",
#             "as_total_charge": "0"
#           },
#           {
#             "as_total_hours": "2.50",
#             "as_rate": "$55.00",
#             "as_financial_privacy": "0",
#             "as_total_charge": "137.5",
#             "as_to": "08/2017",
#             "as_from_full": "08/14/2017",
#             "as_ciphertext_opening_recno": "~010c0a9d116dd3f3b8",
#             "as_total_hours_precise": "2.5",
#             "as_opening_title": "Public Tech Company Seeking Press Release Writer ~ 1 per week",
#             "as_job_type": "Hourly",
#             "as_agency_name": "",
#             "as_to_full": "08/16/2017",
#             "feedback": {
#               "comment": "Marc provided very clear communications to ensure he understood what we were looking for and delivered exactly on deadline. Very professional",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             }
#           },
#           {
#             "as_total_hours": "1.67",
#             "as_rate": "$40.00",
#             "feedback": {
#               "comment": "helped a lot developing our PR strategy!",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_to": "07/2017",
#             "as_total_hours_precise": "1.66666667",
#             "as_opening_title": "public relations for b2b saas startup",
#             "as_job_type": "Hourly",
#             "as_to_full": "07/27/2017"
#           },
#           {
#             "as_to": "Present",
#             "as_rate": "$55.00",
#             "as_total_charge": "146.67",
#             "as_total_hours": "2.67",
#             "as_from_full": "05/09/2017",
#             "as_ciphertext_opening_recno": "~01e7444d2e9ceb48d6",
#             "as_total_hours_precise": "2.66666667",
#             "as_opening_title": "Writer Needed for PRESS RELEASE",
#             "as_job_type": "Hourly",
#             "as_agency_name": "",
#             "as_to_full": "Present",
#             "as_financial_privacy": "0"
#           },
#           {
#             "as_to": "Present",
#             "as_rate": "$52.00",
#             "as_total_charge": "875.34",
#             "as_total_hours": "17",
#             "as_total_hours_precise": "16.83333334",
#             "as_opening_title": "PR for association conf 4/21",
#             "as_job_type": "Hourly",
#             "as_to_full": "Present"
#           },
#           {
#             "as_total_hours": "14",
#             "as_rate": "$75.00",
#             "as_financial_privacy": "0",
#             "as_to": "Present",
#             "as_from_full": "10/03/2016",
#             "as_ciphertext_opening_recno": "~018445f5bd2f040be9",
#             "as_total_hours_precise": "14",
#             "as_opening_title": "IT association seeks freelance PR professional",
#             "as_job_type": "Hourly",
#             "as_to_full": "Present",
#             "as_agency_name": "",
#             "as_total_charge": "1050"
#           }
#         ]
#       },
#       "fp": {
#         "job": [
#           {
#             "as_total_hours": "0.00",
#             "as_rate": "$0.00",
#             "as_to": "Present",
#             "as_total_hours_precise": "0",
#             "as_opening_title": "Announcement",
#             "as_job_type": "Fixed",
#             "as_to_full": "Present"
#           },
#           {
#             "as_total_hours": "0.00",
#             "as_rate": "$0.00",
#             "as_total_charge": "125",
#             "as_to": "Present",
#             "as_from_full": "05/29/2017",
#             "as_ciphertext_opening_recno": "~014b370656fe2ad885",
#             "as_total_hours_precise": "0",
#             "as_opening_title": "Need to hire a freelancer writer for Press Releases for our company",
#             "as_job_type": "Fixed",
#             "as_agency_name": "",
#             "as_to_full": "Present",
#             "as_financial_privacy": "0"
#           },
#           {
#             "as_to": "Present",
#             "as_rate": "$0.00",
#             "as_total_charge": "300",
#             "as_total_hours": "0.00",
#             "as_total_hours_precise": "0",
#             "as_opening_title": "Press Release for Media Startup Company is needed",
#             "as_job_type": "Fixed",
#             "as_to_full": "Present"
#           },
#           {
#             "as_to": "11/2017",
#             "as_rate": "$0.00",
#             "as_total_charge": "120",
#             "as_total_hours": "0.00",
#             "as_from_full": "11/04/2017",
#             "as_ciphertext_opening_recno": "~019588053f7faa7aa3",
#             "feedback": {
#               "comment": "Marc wrote an excellent PR copy on time and within budget, he was able to quickly understand the requirement and produce highly engaging copy within 24 hours. I highly recommend his service !",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_total_hours_precise": "0",
#             "as_opening_title": "Professional Press Release writer is needed",
#             "as_job_type": "Fixed",
#             "as_agency_name": "",
#             "as_to_full": "11/17/2017",
#             "as_financial_privacy": "0"
#           },
#           {
#             "as_to": "10/2017",
#             "as_rate": "$0.00",
#             "as_total_charge": "250",
#             "as_total_hours": "0.00",
#             "as_from_full": "07/21/2017",
#             "as_ciphertext_opening_recno": "~01503c126f5f7f9712",
#             "feedback": {
#               "comment": "",
#               "score": "4.60",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "3",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_total_hours_precise": "0",
#             "as_opening_title": "B2B Press Release (PR)",
#             "as_job_type": "Fixed",
#             "as_agency_name": "",
#             "as_to_full": "10/19/2017",
#             "as_financial_privacy": "0"
#           },
#           {
#             "as_to": "10/2017",
#             "as_rate": "$0.00",
#             "feedback": {
#               "comment": "Great!",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_total_hours": "0.00",
#             "as_total_hours_precise": "0",
#             "as_opening_title": "press release",
#             "as_job_type": "Fixed",
#             "as_to_full": "10/18/2017"
#           },
#           {
#             "as_total_hours": "0.00",
#             "as_rate": "$0.00",
#             "as_total_charge": "50",
#             "as_to": "10/2017",
#             "as_total_hours_precise": "0",
#             "as_opening_title": "Seeking Press Writing Expertise for a Solar Power Company",
#             "as_job_type": "Fixed",
#             "as_to_full": "10/17/2017",
#             "feedback": {
#               "comment": "",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             }
#           },
#           {
#             "as_to": "10/2017",
#             "as_rate": "$0.00",
#             "as_financial_privacy": "0",
#             "as_total_hours": "0.00",
#             "as_from_full": "09/29/2017",
#             "as_ciphertext_opening_recno": "~019a3584f378f82611",
#             "feedback": {
#               "comment": "",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_total_hours_precise": "0",
#             "as_opening_title": "Press Release writer needed for start up tech company!!",
#             "as_job_type": "Fixed",
#             "as_agency_name": "",
#             "as_to_full": "10/02/2017",
#             "as_total_charge": "70"
#           },
#           {
#             "as_total_hours": "0.00",
#             "as_rate": "$0.00",
#             "as_financial_privacy": "0",
#             "as_total_charge": "150",
#             "as_to": "09/2017",
#             "as_from_full": "09/14/2017",
#             "as_ciphertext_opening_recno": "~010f55dde210d52026",
#             "as_total_hours_precise": "0",
#             "as_opening_title": "new to write Press Release",
#             "as_job_type": "Fixed",
#             "as_agency_name": "",
#             "as_to_full": "09/26/2017",
#             "feedback": {
#               "comment": "",
#               "score": "4.80",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "4",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
# ...
#             "as_job_type": "Fixed",
#             "as_to_full": "06/26/2016",
#             "feedback": {
#               "comment": "",
#               "score": "3.65",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "2",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "2",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "4",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             }
#           },
#           {
#             "as_total_hours": "0.00",
#             "as_rate": "$0.00",
#             "as_financial_privacy": "0",
#             "as_to": "05/2016",
#             "as_from_full": "05/29/2016",
#             "as_ciphertext_opening_recno": "~01aadeda1e117ce2a3",
#             "as_total_hours_precise": "0",
#             "as_total_charge": "20",
#             "as_opening_title": "Transalting a document from Dutch to English",
#             "as_job_type": "Fixed",
#             "as_agency_name": "",
#             "as_to_full": "05/31/2016",
#             "feedback": {
#               "comment": "Really good experience with Nicole. She is very punctual and delivers good quality work.",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             }
#           },
#           {
#             "as_to": "05/2016",
#             "as_rate": "$0.00",
#             "as_financial_privacy": "0",
#             "as_total_hours": "0.00",
#             "as_from_full": "05/12/2016",
#             "as_ciphertext_opening_recno": "~0121abf25ac399d6d0",
#             "feedback": {
#               "comment": "Great work! My instructions were minimal but she was very proactive in getting the task completed! Very responsive and thorough. \nI would like to hire her again for future projects.",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_total_hours_precise": "0",
#             "as_opening_title": "Research on antimicrobial resistance and pharmaceutical companies",
#             "as_job_type": "Fixed",
#             "as_agency_name": "",
#             "as_to_full": "05/22/2016",
#             "as_total_charge": "100"
#           },
#           {
#             "as_total_hours": "0.00",
#             "as_rate": "$0.00",
#             "as_financial_privacy": "0",
#             "as_to": "05/2016",
#             "as_from_full": "05/20/2016",
#             "as_ciphertext_opening_recno": "~01d233db79fcb24316",
#             "feedback": {
#               "comment": "I have worked with Nicole on multiple projects and she has always performed exceedingly well each time. Her greatest attribute is that she is a self starter. To be clear, if you give her a specific end state and parameters she will fill in the holes and produce a great well thought out project with minimal supervision. She is open to editing and gives constructive feedback when necessary. Truly a pleasure to work with.",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_total_hours_precise": "0",
#             "as_opening_title": "MeD School Referral Letter",
#             "as_job_type": "Fixed",
#             "as_to_full": "05/21/2016",
#             "as_agency_name": "",
#             "as_total_charge": "100"
#           },
#           {
#             "as_to": "05/2016",
#             "as_rate": "$0.00",
#             "as_total_charge": "100",
#             "as_total_hours": "0.00",
#             "as_from_full": "05/03/2016",
#             "as_ciphertext_opening_recno": "~01d233db79fcb24316",
#             "feedback": {
#               "comment": "Nicole was contracted for an out of the box assignment that was executed in a timely manner flawlessly and with minimum guidance. Her research into the subject matter was well thought out and relevant.",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_total_hours_precise": "0",
#             "as_opening_title": "MeD School Referral Letter",
#             "as_job_type": "Fixed",
#             "as_to_full": "05/11/2016",
#             "as_agency_name": "",
#             "as_financial_privacy": "0"
#           },
#           {
#             "as_total_hours": "0.00",
#             "as_rate": "$0.00",
#             "feedback": {
#               "comment": "Nicole conducted excellent research - she is very thorough, and the work was detailed and precise - exactly what I was looking for. Nicole's communication was good - she sent daily reports as requested, and was very responsive in emails. I will definitely recommend her for future work.",
#               "score": "5.00",
#               "scores": {
#                 "score": [
#                   {
#                     "score": "5",
#                     "description": "competency and skills for the job, understanding of specifications/instructions",
#                     "label": "Skills"
#                   },
#                   {
#                     "score": "5",
#                     "description": "quality of work deliverables",
#                     "label": "Quality"
#                   },
#                   {
#                     "score": "5",
#                     "description": "online presence on a consistent schedule",
#                     "label": "Availability"
#                   },
#                   {
#                     "score": "5",
#                     "description": "ability to complete tasks on time",
#                     "label": "Deadlines"
#                   },
#                   {
#                     "score": "5",
#                     "description": "communication skills, frequent progress updates, responsiveness",
#                     "label": "Communication"
#                   },
#                   {
#                     "score": "5",
#                     "description": "cooperation and flexibility, suggestions for improvement",
#                     "label": "Cooperation"
#                   }
#                 ]
#               }
#             },
#             "as_to": "04/2016",
#             "as_total_hours_precise": "0",
#             "as_opening_title": "Research into a Flemish company (Dutch required)",
#             "as_job_type": "Fixed",
#             "as_to_full": "04/22/2016",
#             "as_total_charge": "245"
#           }
#         ]
#       }
#     },
#     "dev_job_categories_v2": {
#       "dev_job_categories_v": [
#         {
#           "name": "Academic Writing & Research",
#           "groups": {
#             "group": {
#               "uid": "531770282580668423",
#               "name": "Writing"
#             }
#           }
#         },
#         {
#           "name": "Legal Translation",
#           "groups": {
#             "group": {
#               "uid": "531770282584862720",
#               "name": "Translation"
#             }
#           }
#         },
#         {
#           "name": "Graphic Design",
#           "groups": {
#             "group": {
#               "uid": "531770282580668421",
#               "name": "Design & Creative"
#             }
#           }
#         },
#         {
#           "name": "Resumes & Cover Letters",
#           "groups": {
#             "group": {
#               "name": "Writing",
#               "uid": "531770282580668423"
#             }
#           }
#         },
#         {
#           "name": "Grant Writing",
#           "groups": {
#             "group": {
#               "name": "Writing",
#               "uid": "531770282580668423"
#             }
#           }
#         },
#         {
#           "name": "Other - Design & Creative",
#           "groups": {
#             "group": {
#               "uid": "531770282580668421",
#               "name": "Design & Creative"
#             }
#           }
#         },
#         {
#           "name": "Technical Translation",
#           "groups": {
#             "group": {
#               "uid": "531770282584862720",
#               "name": "Translation"
#             }
#           }
#         },
#         {
#           "name": "General Translation",
#           "groups": {
#             "group": {
#               "name": "Translation",
#               "uid": "531770282584862720"
#             }
#           }
#         },
#         {
#           "name": "Medical Translation",
#           "groups": {
#             "group": {
#               "uid": "531770282584862720",
#               "name": "Translation"
#             }
#           }
#         },
#         {
#           "name": "Editing & Proofreading",
#           "groups": {
#             "group": {
#               "name": "Writing",
#               "uid": "531770282580668423"
#             }
#           }
#         }
#       ]
#     },
#     "dev_ac_agencies": "",
#     "dev_short_name": "Nicole S.",
#     "dev_last_worked_ts": "1512864000000",
#     "experiences": {
#       "experience": [
#         {
#           "exp_from": "01/2016",
#           "exp_comment": "",
#           "exp_title_raw": "Research Scientist",
#           "exp_to": "Present",
#           "exp_company": "Geisel School of Medicine at Dartmouth"
#         },
#         {
#           "exp_from": "01/2012",
#           "exp_comment": "",
#           "exp_title_raw": "Instructor in Medicine",
#           "exp_to": "12/2015",
#           "exp_company": "Geisel School of Medicine at Dartmouth"
#         },
#         {
#           "exp_from": "12/2006",
#           "exp_title_raw": "Postdoctoral Fellow",
#           "exp_comment": "",
#           "exp_to": "12/2011",
#           "exp_company": "Geisel School of Medicine at Dartmouth"
#         },
#         {
#           "exp_from": "08/2001",
#           "exp_comment": "",
#           "exp_title_raw": "Graduate Student",
#           "exp_to": "02/2006",
#           "exp_company": "Radboud University Nijmegen Medical Center"
#         }
#       ]
#     },
#     "dev_total_hours": "159.66666666",
#     "dev_last_name": " S."
#   }
# ]
